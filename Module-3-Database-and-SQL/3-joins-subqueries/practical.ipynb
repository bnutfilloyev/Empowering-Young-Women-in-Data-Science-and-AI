# %% [markdown]
# # 🏆 Amaliy mashqlar: JOINlar va Subquerylar
#
# **Modul:** 3 - Database va SQL
# **Dars:** 3
# **Mavzu:** JOIN operatorlari va ichki so'rovlar praktikasi
# **Davomiyligi:** 60 daqiqa
#
# ---
#
# ## 📖 Kirish
#
# Bu amaliy mashqlarda siz lecture.ipynb da o'rgangan JOIN operatorlari va subquerylar bilan ishlashni mashq qilasiz. Har bir mashq uchun:
#
# 1. **Vazifa** - nima qilish kerakligi
# 2. **Maqsad** - qaysi konseptlarni o'rganish
# 3. **Kutilgan natija** - qanday natija kutilyapti
# 4. **Yechim** - sizning kodingiz
#
# ### 💡 Maslahatlar:
# - Har bir mashqni alohida bajarib, natijani tekshiring
# - Agar xatolik yuz bersa, xabarni diqqat bilan o'qing
# - Murakkab mashqlarda birinchi oddiy qismdan boshlang
# - Kodni izohlab qo'ying (comments)
#
# ---

# %%
# Kerakli kutubxonalarni import qilish
import psycopg2
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# Ma'lumotlar bazasiga ulanish
DB_CONFIG = {
    'host': 'localhost',
    'database': 'lesson_joins',
    'user': 'data_scientist',
    'password': 'secure_password123',
    'port': '5432'
}

try:
    conn = psycopg2.connect(**DB_CONFIG)
    engine = create_engine(f"postgresql://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['database']}")
    print("✅ Ma'lumotlar bazasiga ulandi!")
except Exception as e:
    print(f"❌ Ulanishda xatolik: {e}")
    print("ℹ️ create_postgresql_db.py faylini ishga tushirganingizni tekshiring")

# %% [markdown]
# ## 🏃‍♀️ Qism 1: INNER JOIN mashqlari
#
# ### 1.1 Asosiy INNER JOIN
#
# **Vazifa:** Barcha buyurtmalar va ularning mijozlarini ko'rsating
#
# **Ustunlar:** mijoz ismi, buyurtma raqami, buyurtma sanasi, umumiy summa
#
# **Maqsad:** INNER JOIN asoslarini o'rganish

# %%
# 1.1 Yechim
query_1_1 = """
-- Sizning kodingiz shu yerga

"""

print("📋 1.1: Buyurtmalar va mijozlar")
# df_1_1 = pd.read_sql(query_1_1, engine)
# df_1_1.head(10)

# %% [markdown]
# ### 1.2 Multiple INNER JOINs
#
# **Vazifa:** Buyurtma tafsilotlari bilan birga mahsulot va kategoriya ma'lumotlarini ko'rsating
#
# **Ustunlar:** buyurtma raqami, mahsulot nomi, kategoriya nomi, miqdor, narx
#
# **Maqsad:** Bir nechta jadvalni birlashtirish

# %%
# 1.2 Yechim
query_1_2 = """
-- Sizning kodingiz shu yerga

"""

print("📦 1.2: Buyurtma tafsilotlari")
# df_1_2 = pd.read_sql(query_1_2, engine)
# df_1_2.head(10)

# %% [markdown]
# ### 1.3 Agregatsiya bilan INNER JOIN
#
# **Vazifa:** Har bir xodim qancha buyurtma qayta olganini ko'rsating
#
# **Ustunlar:** xodim ismi, bo'lim nomi, buyurtmalar soni, umumiy summa
#
# **Maqsad:** JOIN va GROUP BY birgalikda ishlatish

# %%
# 1.3 Yechim
query_1_3 = """
-- Sizning kodingiz shu yerga

"""

print("👥 1.3: Xodimlar statistikasi")
# df_1_3 = pd.read_sql(query_1_3, engine)
# df_1_3

# %% [markdown]
# ## 🏃‍♀️ Qism 2: LEFT JOIN mashqlari
#
# ### 2.1 Asosiy LEFT JOIN
#
# **Vazifa:** Barcha mijozlarni va ularning buyurtmalarini ko'rsating (buyurtmasi yo'q mijozlarni ham)
#
# **Ustunlar:** mijoz ismi, buyurtmalar soni, oxirgi buyurtma sanasi, umumiy xarid
#
# **Maqsad:** LEFT JOIN ning ishlash prinsipini tushunish

# %%
# 2.1 Yechim
query_2_1 = """
-- Sizning kodingiz shu yerga

"""

print("🛒 2.1: Barcha mijozlar va buyurtmalari")
# df_2_1 = pd.read_sql(query_2_1, engine)
# df_2_1.head(15)

# %% [markdown]
# ### 2.2 LEFT JOIN va filtrlash
#
# **Vazifa:** Buyurtmasi bo'lmagan mijozlarni toping
#
# **Ustunlar:** mijoz ismi, email, ro'yxatdan o'tgan sana
#
# **Maqsad:** NULL qiymatlar bilan ishlash

# %%
# 2.2 Yechim
query_2_2 = """
-- Sizning kodingiz shu yerga

"""

print("❌ 2.2: Buyurtmasi yo'q mijozlar")
# df_2_2 = pd.read_sql(query_2_2, engine)
# df_2_2

# %% [markdown]
# ### 2.3 Multiple LEFT JOINs
#
# **Vazifa:** Barcha mahsulotlarni va ularning sharhlarini ko'rsating
#
# **Ustunlar:** mahsulot nomi, o'rtacha reyting, sharhlar soni, eng oxirgi sharh
#
# **Maqsad:** Murakkab LEFT JOIN so'rovlari

# %%
# 2.3 Yechim
query_2_3 = """
-- Sizning kodingiz shu yerga

"""

print("⭐ 2.3: Mahsulotlar va sharhlari")
# df_2_3 = pd.read_sql(query_2_3, engine)
# df_2_3.head(10)

# %% [markdown]
# ## 🏃‍♀️ Qism 3: RIGHT JOIN va FULL OUTER JOIN
#
# ### 3.1 RIGHT JOIN
#
# **Vazifa:** Barcha bo'limlarni va ulardagi xodimlarni ko'rsating
#
# **Ustunlar:** bo'lim nomi, xodimlar soni, o'rtacha maosh
#
# **Maqsad:** RIGHT JOIN dan foydalanish

# %%
# 3.1 Yechim
query_3_1 = """
-- Sizning kodingiz shu yerga

"""

print("🏢 3.1: Bo'limlar va xodimlar")
# df_3_1 = pd.read_sql(query_3_1, engine)
# df_3_1

# %% [markdown]
# ### 3.2 FULL OUTER JOIN
#
# **Vazifa:** Barcha mijozlar va barcha buyurtmalarni ko'rsating
#
# **Ustunlar:** mijoz ismi, buyurtma raqami, join turi
#
# **Maqsad:** FULL OUTER JOIN ning ishlash prinsipini tushunish

# %%
# 3.2 Yechim
query_3_2 = """
-- Sizning kodingiz shu yerga

"""

print("🔄 3.2: Barcha mijozlar va buyurtmalar")
# df_3_2 = pd.read_sql(query_3_2, engine)
# df_3_2.head(20)

# %% [markdown]
# ## 🏃‍♀️ Qism 4: SELF JOIN
#
# ### 4.1 Xodimlar iyerarxiyasi
#
# **Vazifa:** Xodimlarni va ularning menejerlarini ko'rsating
#
# **Ustunlar:** xodim ismi, menejer ismi, lavozim, maosh farqi
#
# **Maqsad:** SELF JOIN asoslarini o'rganish

# %%
# 4.1 Yechim
query_4_1 = """
-- Sizning kodingiz shu yerga

"""

print("👔 4.1: Xodimlar iyerarxiyasi")
# df_4_1 = pd.read_sql(query_4_1, engine)
# df_4_1.head(10)

# %% [markdown]
# ### 4.2 Kategoriyalar iyerarxiyasi
#
# **Vazifa:** Kategoriyalar va ularning asosiy kategoriyalarini ko'rsating
#
# **Ustunlar:** kichik kategoriya, asosiy kategoriya
#
# **Maqsad:** Iyerarxik ma'lumotlar bilan ishlash

# %%
# 4.2 Yechim
query_4_2 = """
-- Sizning kodingiz shu yerga

"""

print("📂 4.2: Kategoriyalar iyerarxiyasi")
# df_4_2 = pd.read_sql(query_4_2, engine)
# df_4_2

# %% [markdown]
# ## 🏃‍♀️ Qism 5: Subquerylar
#
# ### 5.1 WHERE bandida subquery
#
# **Vazifa:** O'rtacha narxdan qimmat mahsulotlarni toping
#
# **Ustunlar:** mahsulot nomi, narx, kategoriya
#
# **Maqsad:** Scalar subquery dan foydalanish

# %%
# 5.1 Yechim
query_5_1 = """
-- Sizning kodingiz shu yerga

"""

print("💰 5.1: Qimmat mahsulotlar")
# df_5_1 = pd.read_sql(query_5_1, engine)
# df_5_1.head(10)

# %% [markdown]
# ### 5.2 IN operatori bilan subquery
#
# **Vazifa:** Katta shaharlardagi mijozlarni toping
#
# **Ustunlar:** mijoz ismi, shahar, mijoz turi
#
# **Maqsad:** IN operatori va subquery

# %%
# 5.2 Yechim
query_5_2 = """
-- Sizning kodingiz shu yerga

"""

print("🏙️ 5.2: Katta shaharlardagi mijozlar")
# df_5_2 = pd.read_sql(query_5_2, engine)
# df_5_2.head(10)

# %% [markdown]
# ### 5.3 FROM bandida subquery
#
# **Vazifa:** Har bir kategoriyadagi mahsulotlar statistikasini ko'rsating
#
# **Ustunlar:** kategoriya nomi, mahsulotlar soni, o'rtacha narx, min/max narx
#
# **Maqsad:** Subquery ni jadval sifatida ishlatish

# %%
# 5.3 Yechim
query_5_3 = """
-- Sizning kodingiz shu yerga

"""

print("📊 5.3: Kategoriyalar statistikasi")
# df_5_3 = pd.read_sql(query_5_3, engine)
# df_5_3

# %% [markdown]
# ## 🏃‍♀️ Qism 6: Correlated Subqueries
#
# ### 6.1 O'z bo'limidagi o'rtacha maoshdan yuqori
#
# **Vazifa:** O'z bo'limidagi o'rtacha maoshdan ko'proq oluvchi xodimlarni toping
#
# **Ustunlar:** xodim ismi, bo'lim, maosh, bo'lim o'rtachasi
#
# **Maqsad:** Correlated subquery dan foydalanish

# %%
# 6.1 Yechim
query_6_1 = """
-- Sizning kodingiz shu yerga

"""

print("💼 6.1: Yuqori maosh oluvchi xodimlar")
# df_6_1 = pd.read_sql(query_6_1, engine)
# df_6_1

# %% [markdown]
# ### 6.2 Har bir mijozning oxirgi buyurtmasi
#
# **Vazifa:** Har bir mijozning eng oxirgi buyurtmasini toping
#
# **Ustunlar:** mijoz ismi, buyurtma sanasi, summa, status
#
# **Maqsad:** Correlated subquery va aggregation

# %%
# 6.2 Yechim
query_6_2 = """
-- Sizning kodingiz shu yerga

"""

print("🛍️ 6.2: Oxirgi buyurtmalar")
# df_6_2 = pd.read_sql(query_6_2, engine)
# df_6_2.head(10)

# %% [markdown]
# ## 🏃‍♀️ Qism 7: EXISTS va NOT EXISTS
#
# ### 7.1 EXISTS - Buyurtma bergan mijozlar
#
# **Vazifa:** Hech bo'lmaganda bitta buyurtma bergan mijozlarni toping
#
# **Ustunlar:** mijoz ismi, email, ro'yxatdan o'tgan sana
#
# **Maqsad:** EXISTS operatoridan foydalanish

# %%
# 7.1 Yechim
query_7_1 = """
-- Sizning kodingiz shu yerga

"""

print("✅ 7.1: Faol mijozlar")
# df_7_1 = pd.read_sql(query_7_1, engine)
# df_7_1.head(10)

# %% [markdown]
# ### 7.2 NOT EXISTS - Buyurtmasi yo'q mijozlar
#
# **Vazifa:** Hech buyurtma bermagan mijozlarni toping
#
# **Ustunlar:** mijoz ismi, email, ro'yxatdan o'tgan sana
#
# **Maqsad:** NOT EXISTS operatoridan foydalanish

# %%
# 7.2 Yechim
query_7_2 = """
-- Sizning kodingiz shu yerga

"""

print("❌ 7.2: Faol bo'lmagan mijozlar")
# df_7_2 = pd.read_sql(query_7_2, engine)
# df_7_2

# %% [markdown]
# ## 🏃‍♀️ Qism 8: Murakkab mashqlar
#
# ### 8.1 Viloyatlar bo'yicha savdo hisoboti
#
# **Vazifa:** Har bir viloyat uchun quyidagi hisobotni tuzing:
# - Mijozlar soni
# - Buyurtmalar soni
# - Umumiy savdo hajmi
# - O'rtacha buyurtma qiymati
# - Aholi soniga nisbatan savdo ko'rsatkichi
#
# **Maqsad:** Murakkab JOIN va subquery kombinatsiyasi

# %%
# 8.1 Yechim
query_8_1 = """
-- Sizning kodingiz shu yerga

"""

print("📈 8.1: Viloyatlar bo'yicha savdo hisoboti")
# df_8_1 = pd.read_sql(query_8_1, engine)
# df_8_1

# %% [markdown]
# ### 8.2 Top mahsulotlar tahlili
#
# **Vazifa:** Eng ko'p sotilgan mahsulotlarni tahlil qiling:
# - Mahsulot nomi va kategoriyasi
# - Sotilgan umumiy miqdor
# - Umumiy daromad
# - Xaridorlar soni
# - O'rtacha baho
#
# **Maqsad:** Murakkab subquery va JOIN kombinatsiyasi

# %%
# 8.2 Yechim
query_8_2 = """
-- Sizning kodingiz shu yerga

"""

print("🏆 8.2: Top mahsulotlar tahlili")
# df_8_2 = pd.read_sql(query_8_2, engine)
# df_8_2.head(10)

# %% [markdown]
# ### 8.3 Xodimlar samaradorligi tahlili
#
# **Vazifa:** Xodimlarning samaradorligini tahlil qiling:
# - Qayta olgan buyurtmalar soni
# - Umumiy savdo hajmi
# - O'rtacha buyurtma qiymati
# - Maoshiga nisbatan samaradorlik
#
# **Maqsad:** Murakkab hisobot yaratish

# %%
# 8.3 Yechim
query_8_3 = """
-- Sizning kodingiz shu yerga

"""

print("👥 8.3: Xodimlar samaradorligi")
# df_8_3 = pd.read_sql(query_8_3, engine)
# df_8_3

# %% [markdown]
# ## 📝 Yechimlar uchun joy
#
# Quyidagi kataklarda o'z yechimlaringizni yozing. Har bir mashq uchun alohida katakdan foydalaning.
#
# ### Maslahatlar:
# 1. Avval sodda mashqlardan boshlang
# 2. Har bir qadamni tekshiring
# 3. Agar xatolik yuz bersa, xabarni diqqat bilan o'qing
# 4. Kodni izohlab qo'ying
# 5. Natijani tahlil qiling

# %%
# Yechimlar uchun joy
# 1.1

# 1.2

# 1.3

# 2.1

# 2.2

# 2.3

# 3.1

# 3.2

# 4.1

# 4.2

# 5.1

# 5.2

# 5.3

# 6.1

# 6.2

# 7.1

# 7.2

# 8.1

# 8.2

# 8.3

# %% [markdown]
# ## ✅ Tekshirish ro'yxati
#
# Mashqlarni bajarishda quyidagi ro'yxatni belgilang:
#
# - [ ] 1.1 INNER JOIN asoslari
# - [ ] 1.2 Multiple INNER JOINs
# - [ ] 1.3 Agregatsiya bilan INNER JOIN
# - [ ] 2.1 LEFT JOIN asoslari
# - [ ] 2.2 NULL qiymatlar bilan ishlash
# - [ ] 2.3 Multiple LEFT JOINs
# - [ ] 3.1 RIGHT JOIN
# - [ ] 3.2 FULL OUTER JOIN
# - [ ] 4.1 SELF JOIN - xodimlar iyerarxiyasi
# - [ ] 4.2 SELF JOIN - kategoriyalar
# - [ ] 5.1 Scalar subquery
# - [ ] 5.2 IN operatori
# - [ ] 5.3 FROM bandida subquery
# - [ ] 6.1 Correlated subquery
# - [ ] 6.2 Correlated subquery va aggregation
# - [ ] 7.1 EXISTS
# - [ ] 7.2 NOT EXISTS
# - [ ] 8.1 Murakkab hisobot
# - [ ] 8.2 Top mahsulotlar tahlili
# - [ ] 8.3 Xodimlar samaradorligi
#
# ## 🎯 Keyingi qadamlar
#
# 1. **homework.ipynb** faylida uy vazifasini bajarish
# 2. O'z loyihalaringizda JOIN va subquerylardan foydalanish
# 3. Murakkab SQL so'rovlar yozishni mashq qilish
#
# ---
#
# **🎉 Barcha mashqlarni muvaffaqiyatli bajardingiz!**
#
# *Bu material "Empowering Young Women in Data Science and AI" dasturi doirasida tayyorlangan*
