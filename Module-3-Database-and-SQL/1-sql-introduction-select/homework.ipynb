# %% [markdown]
# # 📝 Uy Vazifasi: SQL SELECT Asoslari
#
# ## 🎯 Vazifa maqsadi
# SQL SELECT operatori va uning asosiy komponentlari bo'yicha bilim va ko'nikmalarni mustahkamlash.
#
# ## 📋 Baholash tizimi (100 ball)
#
# ### 📊 Vazifalar taqsimoti:
# - **1-qism: Asosiy SELECT (20 ball)** - 4 ta vazifa x 5 ball
# - **2-qism: WHERE filtrlash (25 ball)** - 5 ta vazifa x 5 ball
# - **3-qism: ORDER BY va LIMIT (20 ball)** - 4 ta vazifa x 5 ball
# - **4-qism: Murakkab so'rovlar (25 ball)** - 5 ta vazifa x 5 ball
# - **5-qism: Tahlil va xulosa (10 ball)** - Yozma tahlil
#
# ### 📏 Baholash mezonlari:
# - **5 ball**: To'liq to'g'ri, optimal kod
# - **4 ball**: To'g'ri, kichik kamchiliklar
# - **3 ball**: Asosan to'g'ri, bir nechta xato
# - **2 ball**: Qisman to'g'ri
# - **1 ball**: Katta xatolar, lekin harakat qilgan
# - **0 ball**: Yechilmagan yoki butunlay noto'g'ri
#
# ---
#
# ## ⏰ Muddat: 1 hafta
# **Topshirish sanasi:** Keyingi darsdan oldin
#
# ---

# %%
# Kutubxonalar va ulanish
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Ma'lumotlar bazalariga ulanish
employees_conn = sqlite3.connect('datasets/employees.db')
products_conn = sqlite3.connect('datasets/products.db')
students_conn = sqlite3.connect('datasets/students.db')

print("📚 UY VAZIFASI: SQL SELECT ASOSLARI")
print("=" * 37)
print("✅ Kutubxonalar yuklandi")
print("✅ Ma'lumotlar bazalariga ulanildi")
print("\n🎯 100 ball uchun barcha vazifalarni bajaring!")

# %% [markdown]
# ## 1️⃣ Asosiy SELECT (20 ball)
#
# ### 📋 Vazifalar:
# Har bir vazifa uchun **5 ball**

# %%
# VAZIFA 1.1 (5 ball): Xodimlar jadvali - ism, lavozim, bo'lim
print("📝 VAZIFA 1.1: Asosiy xodimlar ma'lumoti")
print("=" * 37)
print("🎯 Topshiriq: employees jadvalidan name, position, department ustunlarini oling")
print("📊 Natija: Birinchi 15 ta yozuv")

# Sizning kodingiz:
vazifa_1_1 = """
-- Bu yerga o'z kodingizni yozing


"""

# Bu qatorni to'ldirganingizdan so'ng ishga tushiring
# result_1_1 = pd.read_sql_query(vazifa_1_1, employees_conn)
# print(result_1_1.to_string(index=False))
# print(f"\n✅ Natija: {len(result_1_1)} ta xodim")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 1.2 (5 ball): Hisoblangan ustun - yillik maosh
print("📝 VAZIFA 1.2: Yillik maosh hisoblash")
print("=" * 33)
print("🎯 Topshiriq: name, salary, salary*12 (yearly_salary nomi bilan)")
print("📊 Natija: Birinchi 10 ta yozuv")

# Sizning kodingiz:
vazifa_1_2 = """
-- Bu yerga o'z kodingizni yozing


"""

# result_1_2 = pd.read_sql_query(vazifa_1_2, employees_conn)
# print(result_1_2.to_string(index=False))
# print(f"\n✅ Natija: {len(result_1_2)} ta xodim")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 1.3 (5 ball): Products jadval - mahsulot ma'lumotlari
print("📝 VAZIFA 1.3: Mahsulotlar katalogi")
print("=" * 30)
print("🎯 Topshiriq: products jadvalidan name, category, price, rating")
print("📊 Natija: Birinchi 12 ta mahsulot")

# Sizning kodingiz:
vazifa_1_3 = """
-- Bu yerga o'z kodingizni yozing


"""

# result_1_3 = pd.read_sql_query(vazifa_1_3, products_conn)
# print(result_1_3.to_string(index=False))
# print(f"\n✅ Natija: {len(result_1_3)} ta mahsulot")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 1.4 (5 ball): CASE operatori - yosh kategoriyasi
print("📝 VAZIFA 1.4: Yosh kategoriyalari")
print("=" * 29)
print("🎯 Topshiriq: name, age va yosh kategoriyasi")
print("📋 Kategoriya: <25='Yosh', 25-35='O'rta', >35='Katta'")
print("📊 Natija: Birinchi 8 ta xodim")

# Sizning kodingiz:
vazifa_1_4 = """
-- Bu yerga CASE operatori bilan kod yozing


"""

# result_1_4 = pd.read_sql_query(vazifa_1_4, employees_conn)
# print(result_1_4.to_string(index=False))
# print(f"\n✅ Natija: {len(result_1_4)} ta xodim")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %% [markdown]
# ## 2️⃣ WHERE Filtrlash (25 ball)
#
# ### 📋 Vazifalar:
# Har bir vazifa uchun **5 ball**

# %%
# VAZIFA 2.1 (5 ball): Bo'lim bo'yicha filtrlash
print("📝 VAZIFA 2.1: Marketing bo'limi xodimlari")
print("=" * 37)
print("🎯 Topshiriq: Marketing bo'limidagi barcha xodimlar")
print("📊 Ko'rsatish: name, position, salary, age")

# Sizning kodingiz:
vazifa_2_1 = """
-- Bu yerga WHERE operatori bilan kod yozing


"""

# result_2_1 = pd.read_sql_query(vazifa_2_1, employees_conn)
# print(result_2_1.to_string(index=False))
# print(f"\n✅ Marketing bo'limida: {len(result_2_1)} ta xodim")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 2.2 (5 ball): Raqamli filtrlash
print("📝 VAZIFA 2.2: Yuqori maoshli xodimlar")
print("=" * 33)
print("🎯 Topshiriq: Maoshi 1,300,000 dan ko'p bo'lgan xodimlar")
print("📊 Ko'rsatish: name, position, salary, department")

# Sizning kodingiz:
vazifa_2_2 = """
-- Bu yerga raqamli taqqoslash bilan kod yozing


"""

# result_2_2 = pd.read_sql_query(vazifa_2_2, employees_conn)
# print(result_2_2.to_string(index=False))
# print(f"\n✅ Yuqori maoshlilar: {len(result_2_2)} ta xodim")
# if len(result_2_2) > 0:
#     print(f"📊 O'rtacha maosh: {result_2_2['salary'].mean():,.0f} so'm")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 2.3 (5 ball): AND operatori - murakkab shart
print("📝 VAZIFA 2.3: Yosh IT xodimlar")
print("=" * 25)
print("🎯 Topshiriq: IT bo'limidagi 30 yoshdan kichik xodimlar")
print("📊 Ko'rsatish: name, age, position, salary")

# Sizning kodingiz:
vazifa_2_3 = """
-- Bu yerga AND operatori bilan kod yozing


"""

# result_2_3 = pd.read_sql_query(vazifa_2_3, employees_conn)
# print(result_2_3.to_string(index=False))
# print(f"\n✅ Yosh IT xodimlar: {len(result_2_3)} ta")
# if len(result_2_3) > 0:
#     print(f"📊 O'rtacha yosh: {result_2_3['age'].mean():.1f}")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 2.4 (5 ball): IN operatori
print("📝 VAZIFA 2.4: Ko'p kategoriyali mahsulotlar")
print("=" * 35)
print("🎯 Topshiriq: Elektronika, Kiyim, Kitoblar kategoriyalaridagi mahsulotlar")
print("📊 Ko'rsatish: name, category, price, rating")

# Sizning kodingiz:
vazifa_2_4 = """
-- Bu yerga IN operatori bilan kod yozing


"""

# result_2_4 = pd.read_sql_query(vazifa_2_4, products_conn)
# print(result_2_4.head(10).to_string(index=False))
# print(f"\n✅ Topilgan mahsulotlar: {len(result_2_4)} ta")
# if len(result_2_4) > 0:
#     category_count = result_2_4['category'].value_counts()
#     print("📊 Kategoriyalar bo'yicha:")
#     for cat, count in category_count.items():
#         print(f"   {cat}: {count} ta")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 2.5 (5 ball): BETWEEN va LIKE operatorlari
print("📝 VAZIFA 2.5: Stipendiyachi talabalar")
print("=" * 31)
print("🎯 Topshiriq: GPA 3.5-4.0 oralig'ida va ismida 'a' harfi bo'lgan talabalar")
print("📊 Ko'rsatish: name, faculty, gpa, scholarship")

# Sizning kodingiz:
vazifa_2_5 = """
-- Bu yerga BETWEEN va LIKE operatorlari bilan kod yozing


"""

# result_2_5 = pd.read_sql_query(vazifa_2_5, students_conn)
# print(result_2_5.to_string(index=False))
# print(f"\n✅ Stipendiyachi talabalar: {len(result_2_5)} ta")
# if len(result_2_5) > 0:
#     print(f"📊 O'rtacha GPA: {result_2_5['gpa'].mean():.3f}")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %% [markdown]
# ## 3️⃣ ORDER BY va LIMIT (20 ball)
#
# ### 📋 Vazifalar:
# Har bir vazifa uchun **5 ball**

# %%
# VAZIFA 3.1 (5 ball): Eng yuqori maoshli xodimlar
print("📝 VAZIFA 3.1: Top 10 yuqori maoshli xodimlar")
print("=" * 39)
print("🎯 Topshiriq: Eng yuqori 10 ta maoshli xodim")
print("📊 Ko'rsatish: name, position, salary, department")
print("📈 Tartiblash: Maosh bo'yicha kamayish tartibida")

# Sizning kodingiz:
vazifa_3_1 = """
-- Bu yerga ORDER BY DESC va LIMIT bilan kod yozing


"""

# result_3_1 = pd.read_sql_query(vazifa_3_1, employees_conn)
# print(result_3_1.to_string(index=False))
# print(f"\n✅ Top 10 xodim")
# print(f"📊 Eng yuqori maosh: {result_3_1['salary'].max():,.0f} so'm")
# print(f"📊 10-chi o'rin maoshi: {result_3_1['salary'].min():,.0f} so'm")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 3.2 (5 ball): Yosh bo'yicha tartiblash
print("📝 VAZIFA 3.2: Eng yosh xodimlar")
print("=" * 27)
print("🎯 Topshiriq: Eng yosh 8 ta xodim")
print("📊 Ko'rsatish: name, age, position, hire_date")
print("📈 Tartiblash: Yosh bo'yicha o'sish tartibida")

# Sizning kodingiz:
vazifa_3_2 = """
-- Bu yerga ORDER BY ASC va LIMIT bilan kod yozing


"""

# result_3_2 = pd.read_sql_query(vazifa_3_2, employees_conn)
# print(result_3_2.to_string(index=False))
# print(f"\n✅ Eng yosh 8 ta xodim")
# print(f"📊 Eng yosh: {result_3_2['age'].min()} yosh")
# print(f"📊 O'rtacha yosh: {result_3_2['age'].mean():.1f} yosh")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 3.3 (5 ball): Ko'p ustun bo'yicha tartiblash
print("📝 VAZIFA 3.3: Bo'lim va maosh bo'yicha tartiblash")
print("=" * 43)
print("🎯 Topshiriq: Avval bo'lim (A-Z), keyin maosh (yuqoridan pastga)")
print("📊 Ko'rsatish: department, name, position, salary")
print("📊 Natija: Birinchi 15 ta xodim")

# Sizning kodingiz:
vazifa_3_3 = """
-- Bu yerga ko'p ustun bo'yicha ORDER BY bilan kod yozing


"""

# result_3_3 = pd.read_sql_query(vazifa_3_3, employees_conn)
# print(result_3_3.to_string(index=False))
# print(f"\n✅ {len(result_3_3)} ta xodim bo'lim va maosh bo'yicha tartiblandi")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 3.4 (5 ball): OFFSET bilan sahifalash
print("📝 VAZIFA 3.4: Sahifalash (2-sahifa)")
print("=" * 31)
print("🎯 Topshiriq: Eng qimmat mahsulotlarning 6-10 o'rinlari")
print("📊 Ko'rsatish: name, category, price, rating")
print("📈 Tartiblash: Narx bo'yicha kamayish tartibida")

# Sizning kodingiz:
vazifa_3_4 = """
-- Bu yerga LIMIT va OFFSET bilan kod yozing


"""

# result_3_4 = pd.read_sql_query(vazifa_3_4, products_conn)
# print(result_3_4.to_string(index=False))
# print(f"\n✅ 2-sahifa (6-10 o'rin) mahsulotlar")
# print(f"📊 O'rtacha narx: {result_3_4['price'].mean():.2f}")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %% [markdown]
# ## 4️⃣ Murakkab So'rovlar (25 ball)
#
# ### 📋 Vazifalar:
# Har bir vazifa uchun **5 ball**

# %%
# VAZIFA 4.1 (5 ball): Eng murakkab xodimlar so'rovi
print("📝 VAZIFA 4.1: Elite xodimlar")
print("=" * 25)
print("🎯 Topshiriq: IT/Marketing bo'limidagi, yoshi 28-45 oralig'ida,")
print("   maoshi 1M dan ko'p, 2022-yildan keyin ishga qabul qilingan xodimlar")
print("📊 Ko'rsatish: name, age, position, salary, hire_date, department")
print("📈 Tartiblash: maosh kamayish, yosh o'sish")

# Sizning kodingiz:
vazifa_4_1 = """
-- Bu yerga barcha shartlarni birlashtirgan murakkab so'rov yozing


"""

# result_4_1 = pd.read_sql_query(vazifa_4_1, employees_conn)
# print(result_4_1.to_string(index=False))
# print(f"\n✅ Elite xodimlar: {len(result_4_1)} ta")
# if len(result_4_1) > 0:
#     print(f"📊 O'rtacha yosh: {result_4_1['age'].mean():.1f}")
#     print(f"📊 O'rtacha maosh: {result_4_1['salary'].mean():,.0f} so'm")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 4.2 (5 ball): Premium mahsulotlar tahlili
print("📝 VAZIFA 4.2: Premium mahsulotlar")
print("=" * 30)
print("🎯 Topshiriq: Reyting 4.2+ dan yuqori, narxi 200-800 oralig'ida,")
print("   zaxirasi 10+ bo'lgan mahsulotlar")
print("📊 Ko'rsatish: name, category, price, rating, stock, supplier")
print("📊 Qo'shimcha: Narx kategoriyasi (CASE)")

# Sizning kodingiz:
vazifa_4_2 = """
-- Bu yerga CASE bilan narx kategoriyasi qo'shgan murakkab so'rov yozing
-- Narx kategoriyasi: <300='Arzon', 300-500='O'rtacha', >500='Qimmat'


"""

# result_4_2 = pd.read_sql_query(vazifa_4_2, products_conn)
# print(result_4_2.to_string(index=False))
# print(f"\n✅ Premium mahsulotlar: {len(result_4_2)} ta")
# if len(result_4_2) > 0:
#     print(f"📊 O'rtacha reyting: {result_4_2['rating'].mean():.2f}")
#     print(f"📊 O'rtacha narx: {result_4_2['price'].mean():.2f}")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 4.3 (5 ball): Top talabalar tahlili
print("📝 VAZIFA 4.3: A'lo talabalar")
print("=" * 25)
print("🎯 Topshiriq: GPA 3.7+ bo'lgan, 3-4 kurslardagi talabalar")
print("📊 Ko'rsatish: name, faculty, course, gpa, city")
print("📊 Qo'shimcha: GPA foizi va akademik daraja (CASE)")

# Sizning kodingiz:
vazifa_4_3 = """
-- Bu yerga GPA*25 (foiz) va akademik daraja bilan so'rov yozing
-- Daraja: GPA 3.9+='Excellent', 3.7+='Good', boshqalar='Average'


"""

# result_4_3 = pd.read_sql_query(vazifa_4_3, students_conn)
# print(result_4_3.to_string(index=False))
# print(f"\n✅ A'lo talabalar: {len(result_4_3)} ta")
# if len(result_4_3) > 0:
#     print(f"📊 O'rtacha GPA: {result_4_3['gpa'].mean():.3f}")
#     grade_counts = result_4_3['academic_level'].value_counts()
#     print("📊 Darajalar bo'yicha taqsimot:")
#     for grade, count in grade_counts.items():
#         print(f"   {grade}: {count} ta")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 4.4 (5 ball): Maosh darajasi tahlili
print("📝 VAZIFA 4.4: Maosh darajasi bo'yicha tahlil")
print("=" * 37)
print("🎯 Topshiriq: Barcha xodimlarni maosh darajasi bo'yicha kategoriyalash")
print("📊 Ko'rsatish: name, department, age, salary, salary_level, career_stage")
print("📋 Maosh: <800K='Junior', 800K-1.2M='Middle', 1.2M-1.8M='Senior', >1.8M='Lead'")
print("📋 Martaba: <25='Entry', 25-35='Experienced', >35='Expert'")

# Sizning kodingiz:
vazifa_4_4 = """
-- Bu yerga 2 ta CASE operatori bilan murakkab so'rov yozing


"""

# result_4_4 = pd.read_sql_query(vazifa_4_4, employees_conn)
# print(result_4_4.head(15).to_string(index=False))
# print(f"\n✅ Barcha xodimlar kategoriyalandi: {len(result_4_4)} ta")
# if len(result_4_4) > 0:
#     salary_counts = result_4_4['salary_level'].value_counts()
#     career_counts = result_4_4['career_stage'].value_counts()
#     print("📊 Maosh darajasi taqsimoti:")
#     for level, count in salary_counts.items():
#         print(f"   {level}: {count} ta")
#     print("📊 Martaba bosqichi taqsimoti:")
#     for stage, count in career_counts.items():
#         print(f"   {stage}: {count} ta")

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %%
# VAZIFA 4.5 (5 ball): Ijodiy so'rov - o'zingiz yarating!
print("📝 VAZIFA 4.5: IJODIY LOYIHA")
print("=" * 27)
print("🎯 Topshiriq: O'zingiz uchun qiziqarli va murakkab so'rov yarating")
print("📋 Talablar:")
print("   • Kamida 3 ta shart (WHERE)")
print("   • Hisoblangan ustun")
print("   • CASE operatori")
print("   • ORDER BY")
print("   • LIMIT")
print("\n💡 G'oya misollari:")
print("   - 'Eng istiqbolli yosh mutaxassislar'")
print("   - 'Regional eng yaxshi talabalar'")
print("   - 'Eng foydali mahsulotlar'")

# Sizning ijodiy kodingiz:
ijodiy_mavzu = ""  # Bu yerga mavzungizni yozing

ijodiy_vazifa = """
-- Bu yerga o'zingizning ijodiy so'rovingizni yozing
-- Mavzu: [Mavzungizni yozing]
-- Maqsad: [Nima uchun ushbu so'rov foydali ekanligini tushuntiring]


"""

# Qaysi ma'lumotlar bazasi bilan ishlayotganingizni belgilang:
# ishlatilayotgan_db = employees_conn  # yoki products_conn, students_conn

# ijodiy_result = pd.read_sql_query(ijodiy_vazifa, ishlatilayotgan_db)
# print(f"\n🏆 IJODIY LOYIHA: {ijodiy_mavzu}")
# print(ijodiy_result.to_string(index=False))
# print(f"\n✅ {len(ijodiy_result)} ta natija topildi")
# print("\n📊 Tahlil:")
# # Bu yerga o'z tahlilngizni qo'shing

print("\n⚠️  Kodni to'ldirganingizdan so'ng comment ni o'chiring")

# %% [markdown]
# ## 5️⃣ Tahlil va Xulosa (10 ball)
#
# ### 📝 Yozma tavsif va tahlil
#
# **Quyidagi savollarga batafsil javob bering:**

# %% [markdown]
# ### ❓ SAVOL 5.1 (2 ball): SELECT operatori haqida
#
# **Savol:** SELECT operatorining asosiy vazifasi nima va u qanday tuzilgan?
#
# **Sizning javobingiz:**
#
# ```
# Bu yerga yozing...
# ```

# %% [markdown]
# ### ❓ SAVOL 5.2 (2 ball): WHERE vs HAVING
#
# **Savol:** WHERE va HAVING operatorlari o'rtasidagi farq nima? Misollar bilan tushuntiring.
#
# **Sizning javobingiz:**
#
# ```
# Bu yerga yozing...
# ```

# %% [markdown]
# ### ❓ SAVOL 5.3 (2 ball): ORDER BY qo'llanilishi
#
# **Savol:** ORDER BY operatorini qanday hollarda ASC, qanday hollarda DESC ishlatish kerak?
#
# **Sizning javobingiz:**
#
# ```
# Bu yerga yozing...
# ```

# %% [markdown]
# ### ❓ SAVOL 5.4 (2 ball): LIMIT ning ahamiyati
#
# **Savol:** LIMIT operatori nima uchun muhim? Real loyihalarda qanday foydalaniladi?
#
# **Sizning javobingiz:**
#
# ```
# Bu yerga yozing...
# ```

# %% [markdown]
# ### ❓ SAVOL 5.5 (2 ball): Shaxsiy tajriba
#
# **Savol:** Ushbu uy vazifasini bajarish jarayonida qanday qiyinchiliklarga duch keldingiz va qanday hal qildingiz?
#
# **Sizning javobingiz:**
#
# ```
# Bu yerga yozing...
# ```

# %% [markdown]
# ## 📊 Natijalarni Taqdim Etish
#
# ### 🎯 Oxirgi bosqich - natijalaringizni tekshiring

# %%
# Oxirgi tekshirish va statistika
print("📊 UY VAZIFASI YAKUNIY HISOBOTI")
print("=" * 33)

# Ma'lumotlar bazalaridan umumiy statistika
employees_total = pd.read_sql_query("SELECT COUNT(*) as count FROM employees", employees_conn)['count'][0]
products_total = pd.read_sql_query("SELECT COUNT(*) as count FROM products", products_conn)['count'][0] 
students_total = pd.read_sql_query("SELECT COUNT(*) as count FROM students", students_conn)['count'][0]

print(f"\n📈 MA'LUMOTLAR BAZASI STATISTIKASI:")
print(f"   👥 Xodimlar: {employees_total} ta")
print(f"   🛍️ Mahsulotlar: {products_total} ta")
print(f"   🎓 Talabalar: {students_total} ta")

print(f"\n✅ BAJARGAN VAZIFALARINGIZ:")
print(f"   📝 1-qism: Asosiy SELECT (20 ball)")
print(f"   🔍 2-qism: WHERE filtrlash (25 ball)")
print(f"   📊 3-qism: ORDER BY va LIMIT (20 ball)")
print(f"   🔗 4-qism: Murakkab so'rovlar (25 ball)")
print(f"   📝 5-qism: Tahlil va xulosa (10 ball)")
print(f"\n🎯 JAMI: 100 ball")

print(f"\n💡 ESLATMA:")
print(f"   • Barcha so'rovlaringiz ishlayotganini tekshiring")
print(f"   • Comment qatorlarini o'chiring")
print(f"   • Tahlil qismini to'ldiring")
print(f"   • Ijodiy loyihani unutmang")

print(f"\n🚀 Muvaffaqiyatlar tilaymiz!")

# %%
# Ma'lumotlar bazasi ulanishlarini yopish
employees_conn.close()
products_conn.close()
students_conn.close()

print("🔐 Ma'lumotlar bazasi ulanishlari yopildi")
print("\n📚 UY VAZIFASI TUGADI!")
print("\n📋 TOPSHIRISHDAN OLDIN TEKSHIRING:")
print("   ✅ Barcha kodlar ishlaydi")
print("   ✅ Natijalar mantiqiy")
print("   ✅ Tahlil to'liq yozilgan")
print("   ✅ Ijodiy vazifa bajarilgan")
print("\n🎉 OMAD!")

# %% [markdown]
# ---
#
# ## 📋 Baholash jadvali (O'qituvchi uchun)
#
# | Vazifa | Maksimal ball | Olingan ball | Izoh |
# |--------|---------------|--------------|------|
# | 1.1-1.4 Asosiy SELECT | 20 | | |
# | 2.1-2.5 WHERE filtrlash | 25 | | |
# | 3.1-3.4 ORDER BY/LIMIT | 20 | | |
# | 4.1-4.5 Murakkab so'rovlar | 25 | | |
# | 5.1-5.5 Tahlil va xulosa | 10 | | |
# | **JAMI** | **100** | | |
#
# ### 📊 Baho mezonlari:
# - **90-100 ball**: A'lo (5)
# - **80-89 ball**: Yaxshi (4)
# - **70-79 ball**: Qoniqarli (3)
# - **60-69 ball**: Qoniqarsiz (2)
# - **0-59 ball**: Yomon (1)
#
# ---
#
# **📅 Topshirish muddati:** Keyingi darsdan oldin
# **👨‍🏫 O'qituvchi:** AI Data Science Mentor
# **📧 Savollar:** Dars vaqtida yoki maxsus vaqtlarda
