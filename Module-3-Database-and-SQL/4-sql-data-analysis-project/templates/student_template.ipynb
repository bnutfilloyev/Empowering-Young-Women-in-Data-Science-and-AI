# %% [markdown]
# # 🎓 Talaba Uchun Amaliy Mashq: SQL bilan Ma'lumotlar Tahlili
#
# **Maqsad**: Bu template orqali siz SQL bilan ma'lumotlar tahlili texnikalarini mustaqil ravishda mashq qilasiz.
#
# **Qoidalar**:
# - Har bir bo'limda berilgan vazifalarni bajarishga harakat qiling
# - SQL so'rovlaringizni yozing va natijalarni tahlil qiling
# - `# SIZNING KODINGIZ` qismiga o'z kodlaringizni yozing
# - Mushkul bo'lsa, `project_analysis.ipynb` faylidan yordam oling
#
# **Eslatma**: Ma'lumotlar bazasi allaqachon yaratilgan va tayyor!

# %% [markdown]
# ## 📚 1-Bosqich: Kutubxonalar va Ma'lumotlar Bazasiga Ulanish

# %%
# SIZNING KODINGIZ: Kerakli kutubxonalarni import qiling
# Masalan: pandas, sqlite3, matplotlib, seaborn

# SIZNING KODINGIZ bu yerda...

# %%
# SIZNING KODINGIZ: Ma'lumotlar bazasiga ulanish
# 'datasets/ecommerce_data.db' faylini ulang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 🔍 2-Bosqich: Ma'lumotlar Bazasini O'rganish
#
# **Vazifa 1**: Mavjud jadvallar ro'yxatini chiqaring

# %%
# SIZNING KODINGIZ: Jadvallar ro'yxatini ko'rsating
# Maslahat: PRAGMA table_list yoki .tables dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 2**: Har bir jadvalning tuzilishini (schema) ko'ring

# %%
# SIZNING KODINGIZ: customers jadvali tuzilishi

# SIZNING KODINGIZ bu yerda...

# %%
# SIZNING KODINGIZ: products jadvali tuzilishi

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 3**: Har bir jadvalda nechta yozuv borligini aniqlang

# %%
# SIZNING KODINGIZ: Barcha jadvallar uchun COUNT(*) ni hisoblang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 📊 3-Bosqich: Asosiy Statistika
#
# **Vazifa 4**: Mahsulotlar narxlari bo'yicha statistika

# %%
# SIZNING KODINGIZ: Mahsulotlar narxlari uchun MIN, MAX, AVG ni hisoblang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 5**: Kategoriya bo'yicha mahsulotlar soni

# %%
# SIZNING KODINGIZ: Har bir kategoriyada nechta mahsulot borligini aniqlang
# JOIN va GROUP BY dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 🛒 4-Bosqich: Buyurtmalar Tahlili
#
# **Vazifa 6**: Umumiy daromad va buyurtmalar soni

# %%
# SIZNING KODINGIZ: Jami daromad va buyurtmalar sonini hisoblang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 7**: Eng yuqori 10 ta buyurtma

# %%
# SIZNING KODINGIZ: Eng katta miqdordagi 10 ta buyurtmani ko'rsating
# ORDER BY va LIMIT dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 👥 5-Bosqich: Mijozlar Tahlili
#
# **Vazifa 8**: Eng ko'p xarid qilgan mijozlar

# %%
# SIZNING KODINGIZ: Eng ko'p pul sarflagan 10 ta mijozni toping
# customers va orders jadvallarini JOIN qiling

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 9**: Shaharlar bo'yicha mijozlar taqsimoti

# %%
# SIZNING KODINGIZ: Har bir shaharda nechta mijoz borligini aniqlang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 📅 6-Bosqich: Vaqt bo'yicha Tahlil
#
# **Vazifa 10**: Oylik buyurtmalar trendi

# %%
# SIZNING KODINGIZ: Har oy necha buyurtma bo'lganini ko'rsating
# strftime('%Y-%m', order_date) dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 11**: Hafta kunlari bo'yicha faollik

# %%
# SIZNING KODINGIZ: Qaysi kunlarda ko'proq buyurtma berilishini aniqlang
# strftime('%w', order_date) va CASE dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 🏆 7-Bosqich: Ilg'or Tahlil (Advanced)
#
# **Vazifa 12**: TOP mahsulotlar (eng ko'p sotilgan)

# %%
# SIZNING KODINGIZ: Eng ko'p sotilgan 10 ta mahsulotni toping
# order_items jadvali bilan ishlang

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# **Vazifa 13**: Har bir kategoriyada eng qimmat mahsulot

# %%
# SIZNING KODINGIZ: Har bir kategoriyada eng qimmat mahsulotni toping
# Window function yoki subquery dan foydalaning

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 📈 8-Bosqich: Vizualizatsiya uchun Ma'lumotlar
#
# **Vazifa 14**: Grafik uchun ma'lumotlarni tayyorlang

# %%
# SIZNING KODINGIZ: Kategoriya bo'yicha daromad ma'lumotlarini oling
# Keyin pie chart yoki bar chart yarating

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## 🎯 9-Bosqich: O'z Savolaringiz
#
# **Vazifa 15**: O'zingiz 3 ta qiziqarli savol tuzib, SQL orqali javob toping

# %%
# SIZNING SAVOL 1: (masalan, "Qaysi oy eng yuqori daromad keltirgan?")

# SIZNING KODINGIZ bu yerda...

# %%
# SIZNING SAVOL 2:

# SIZNING KODINGIZ bu yerda...

# %%
# SIZNING SAVOL 3:

# SIZNING KODINGIZ bu yerda...

# %% [markdown]
# ## ✅ Yakunlash
#
# **Tabriklaymiz!** 🎉 Siz SQL bilan ma'lumotlar tahlili asoslarini o'rgandingiz!
#
# ### O'rganganlaringiz:
# - ✅ Ma'lumotlar bazasiga ulanish
# - ✅ Jadvallar bilan ishlash
# - ✅ Agregatsiya funksiyalari (COUNT, SUM, AVG, etc.)
# - ✅ GROUP BY va ORDER BY
# - ✅ JOIN operatsiyalari
# - ✅ Vaqt bilan ishlash
# - ✅ Murakkab so'rovlar
#
# ### Keyingi qadamlar:
# 1. `project_analysis.ipynb` faylini o'rganing
# 2. Boshqa real ma'lumotlar bilan mashq qiling
# 3. PostgreSQL, MySQL kabi boshqa DBMS'lar bilan ishlang
# 4. Power BI, Tableau kabi BI vositalarini o'rganing

# %%
# Ma'lumotlar bazasi ulanishini yoping
# SIZNING KODINGIZ bu yerda...
