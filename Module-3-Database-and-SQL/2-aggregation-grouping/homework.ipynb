# %% [markdown]
# # 📚 Uy Vazifasi - PostgreSQL Agregatsiya va Guruhlash
# ## Module 3: Database va SQL - Dars 2
#
# ### 👨‍🎓 Talaba ma'lumotlari:
# - **Ism, Familiya:** ________________
# - **Guruh:** ________________
# - **Sana:** ________________
# - **Ustoz:** ________________
#
# ---
#
# ## 🎯 Vazifa haqida
#
# **Scenariy:** Siz "DataMart" kompaniyasining junior ma'lumotlar tahlilchisisiz. Kompaniya sizdan PostgreSQL ma'lumotlar bazasi yordamida to'liq biznes-tahlil hisoboti tayyorlashni so'ramoqda.
#
# ### 📋 Baholash tizimi:
# - **Jami:** 100 ball
# - **O'tish balli:** 70 ball
# - **Deadline:** _____ (ustoz belgilaydi)
#
# ### ⚠️ Muhim eslatmalar:
# 1. Barcha SQL so'rovlaringiz to'g'ri ishlashi kerak
# 2. Natijalarni tahlil qilib, xulosalar chiqaring
# 3. Grafiklar va vizualizatsiya qo'shing
# 4. O'z fikr va tavsiyalaringizni yozing
# 5. Kod va natijalarni aniq formatda taqdim eting
#
# ---

# %% [markdown]
# ## 🔌 1-Qism: Tizimga ulanish va tekshirish (10 ball)
#
# ### Vazifa 1.1: PostgreSQL ga ulanish (5 ball)

# %%
# TODO: Kerakli kutubxonalarni import qiling va PostgreSQL ga ulaning
# Kutubxonalar: psycopg2, pandas, sqlalchemy, matplotlib, seaborn

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 1.2: Ma'lumotlar bazasi strukturasini o'rganish (5 ball)

# %%
# TODO: 
# 1. Barcha jadvallar ro'yxatini chiqaring
# 2. Har bir jadvaldagi yozuvlar sonini ko'rsating
# 3. Asosiy jadvallarning strukturasini tekshiring

# Sizning kodingiz:

# %% [markdown]
# ---
#
# ## 📊 2-Qism: COUNT funksiyasi bilan ishlash (15 ball)
#
# ### Vazifa 2.1: Asosiy COUNT operatsiyalari (5 ball)

# %%
# TODO: Quyidagi savollarга javob bering:
# 1. Jami nechta mijoz bor?
# 2. Faol mijozlar soni?
# 3. Jami xodimlar soni?
# 4. Jami mahsulotlar soni?

# Sizning kodingiz:

# Javoblar:
# 1. Jami mijozlar: _____ ta
# 2. Faol mijozlar: _____ ta
# 3. Jami xodimlar: _____ ta 
# 4. Jami mahsulotlar: _____ ta

# %% [markdown]
# ### Vazifa 2.2: Bo'limlar bo'yicha COUNT (5 ball)

# %%
# TODO: Bo'limlar bo'yicha xodimlar sonini hisoblang
# Natijani xodimlar soni bo'yicha kamayish tartibida chiqaring
# Foiz hisobini ham qo'shing

# Sizning kodingiz:

# Tahlil va xulosa (bu bo'limni to'ldiring):
# Eng katta bo'lim: _______________
# Eng kichik bo'lim: _______________
# Sizning xulosangiz: _______________

# %% [markdown]
# ### Vazifa 2.3: Shartli COUNT (5 ball)

# %%
# TODO: Har bir hudud uchun quyidagilarni hisoblang:
# - Jami mijozlar soni
# - Faol mijozlar soni
# - Nofaol mijozlar soni
# - VIP mijozlar soni (agar mavjud bo'lsa)
# CASE WHEN dan foydalaning

# Sizning kodingiz:

# Tahlil:
# Eng ko'p mijoz bo'lgan hudud: _______________
# Faol mijozlar foizi eng yuqori hudud: _______________

# %% [markdown]
# ---
#
# ## 💰 3-Qism: SUM va AVG funksiyalari (20 ball)
#
# ### Vazifa 3.1: Maosh tahlili (7 ball)

# %%
# TODO: Bo'limlar bo'yicha to'liq maosh statistikasini hisoblang:
# - Jami maosh fondi (SUM)
# - O'rtacha maosh (AVG)
# - Minimal maosh (MIN)
# - Maksimal maosh (MAX)
# - Maosh diapazoni (MAX - MIN)
# - Standart og'ish (STDDEV)

# Sizning kodingiz:

# Tahlil va xulosalar:
# Eng yuqori o'rtacha maoshli bo'lim: _______________
# Eng katta maosh diapazoni bo'limi: _______________
# Maosh taqsimoti haqida xulosangiz: _______________

# %% [markdown]
# ### Vazifa 3.2: Sotuvlar daromadi (7 ball)

# %%
# TODO: Kategoriyalar bo'yicha sotuvlar statistikasini hisoblang:
# - Jami savdo daromadi
# - O'rtacha sotish narxi
# - Jami sotilgan miqdor
# - Foyda summasi
# - Foyda foizi
# Natijani daromad bo'yicha kamayish tartibida chiqaring

# Sizning kodingiz:

# Biznes tahlili:
# Eng foydali kategoriya: _______________
# Eng kam foydali kategoriya: _______________
# Tavsiyangiz: _______________

# %% [markdown]
# ### Vazifa 3.3: Mijozlar xaridlari (6 ball)

# %%
# TODO: Mijoz turlari bo'yicha xarid tahlili:
# - O'rtacha buyurtma qiymati
# - Jami sarflagan summasi
# - Buyurtmalar soni
# - Eng qimmat bitta xarid
# - Mijoz segmentatsiyasi (yuqori, o'rta, past)

# Sizning kodingiz:

# Marketing xulosalari:
# Eng qimmatbaho mijoz turi: _______________
# Marketing strategiyasi tavsiyasi: _______________

# %% [markdown]
# ---
#
# ## 🔢 4-Qism: GROUP BY va HAVING (25 ball)
#
# ### Vazifa 4.1: Murakkab guruhlash (10 ball)

# %%
# TODO: Hudud va kategoriya bo'yicha ikki darajali guruhlash:
# - Har bir hudud va kategoriya uchun:
#   * Sotuvlar soni
#   * Jami daromad  
#   * O'rtacha sotish narxi
#   * Bozor ulushi (hudud ichida)
# - Faqat 5+ ta sotuv bo'lgan guruhlar
# - Natijani daromad bo'yicha tartibla

# Sizning kodingiz:

# Geografik tahlil:
# Eng yaxshi hudud+kategoriya kombinatsiyasi: _______________
# Rivojlantirish zarur bo'lgan hududlar: _______________

# %% [markdown]
# ### Vazifa 4.2: HAVING bilan filtrlash (8 ball)

# %%
# TODO: Quyidagi shartlarga javob beradigan bo'limlarni toping:
# - Jami maosh fondi 50 mln so'mdan ko'p
# - Xodimlar soni 3 dan ko'p  
# - O'rtacha maosh umumiy o'rtachadan yuqori
# - Ish samaradorligi (savdo/maosh) 2.0 dan yuqori

# Sizning kodingiz:

# TOP bo'limlar tahlili:
# Eng samarali bo'lim: _______________
# Yaxshilash kerak bo'lgan bo'lim: _______________

# %% [markdown]
# ### Vazifa 4.3: Vaqt seriyali tahlil (7 ball)

# %%
# TODO: Oylik sotuvlar dinamikasini tahlil qiling:
# - Har oy uchun jami daromad
# - Buyurtmalar soni
# - O'rtacha buyurtma qiymati
# - Oldingi oyga nisbatan o'sish foizi
# - Trend tahlili (o'sish/kamayish)
# DATE_TRUNC yoki TO_CHAR dan foydalaning

# Sizning kodingiz:

# Vaqt tahlili:
# Eng yaxshi oy: _______________
# Eng yomon oy: _______________
# Umumiy trend: _______________

# %% [markdown]
# ---
#
# ## 📈 5-Qism: Murakkab SQL so'rovlar (20 ball)
#
# ### Vazifa 5.1: CTE (Common Table Expression) (8 ball)

# %%
# TODO: CTE yordamida murakkab tahlil qiling:
# 1. Har bir mijoz uchun loyalty score hisoblang:
#    - Buyurtmalar soni (30%)
#    - Jami sarflagan pul (50%)
#    - Oxirgi xarid sanasi (20%)
# 2. Mijozlarni 5 ta kategoriyaga ajrating:
#    - VIP (top 10%)
#    - Gold (11-25%)
#    - Silver (26-50%)
#    - Bronze (51-80%)
#    - Basic (81-100%)

# Sizning kodingiz:

# Mijoz segmentatsiyasi tahlili:
# VIP mijozlar soni: _______________
# Har bir segment uchun strategiya: _______________

# %% [markdown]
# ### Vazifa 5.2: Window Functions (7 ball)

# %%
# TODO: Window functions yordamida reyting tizimini yarating:
# 1. Har bir bo'limdagi xodimlarni maosh bo'yicha tartiblang
# 2. Har bir xodim uchun hisoblang:
#    - Bo'lim ichidagi reyting (RANK)
#    - Percentile (PERCENT_RANK)
#    - Bo'lim o'rtachasi bilan taqqoslash
#    - Oldingi va keyingi xodim maoshi (LAG, LEAD)
# 3. TOP 3 va BOTTOM 3 xodimlarni aniqlang

# Sizning kodingiz:

# Xodimlar reytingi tahlili:
# Eng yuqori maoshli xodim: _______________
# Eng past maoshli xodim: _______________
# Reyting tizimi haqida xulosangiz: _______________

# %% [markdown]
# ### Vazifa 5.3: Murakkab JOIN va Sub-query (5 ball)

# %%
# TODO: Quyidagi murakkab tahlilni amalga oshiring:
# 1. Har bir mahsulot uchun quyidagilarni hisoblang:
#    - Sotuvlar soni
#    - Daromad
#    - Kategoriya ichidagi reyting
#    - Umumiy bozordagi ulush
# 2. Faqat TOP 20% mahsulotlarni ko'rsating
# 3. Har bir kategoriyadan kamida 1 ta mahsulot bo'lsin

# Sizning kodingiz:

# Mahsulotlar portfolio tahlili:
# Hit mahsulotlar: _______________
# Yaxshilash kerak bo'lgan mahsulotlar: _______________

# %% [markdown]
# ---
#
# ## 📊 6-Qism: Vizualizatsiya va Taqdimot (10 ball)
#
# ### Vazifa 6.1: Dashboard yaratish (7 ball)

# %%
# TODO: 6 ta grafik bilan dashboard yarating:
# 1. Bo'limlar bo'yicha xodimlar (Pie chart)
# 2. Kategoriyalar bo'yicha daromad (Bar chart)
# 3. Hududlar bo'yicha sotuvlar (Horizontal bar)
# 4. Oylik trend (Line chart)
# 5. Maosh vs Samaradorlik (Scatter plot)
# 6. TOP mijozlar (Bar chart)

# Har bir grafik uchun:
# - To'g'ri rang sxemasini tanlang
# - Aniq sarlavha qo'ying
# - Axis labellarini qo'ying
# - Legend qo'shing (kerak bo'lsa)

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 6.2: Xulosalar va tavsiyalar (3 ball)

# %% [markdown]
# **TODO: Quyidagi bo'limlarni to'ldiring:**
#
# #### 📊 Asosiy topilmalar:
# 1. _______________
# 2. _______________
# 3. _______________
# 4. _______________
# 5. _______________
#
# #### 💡 Biznes uchun tavsiyalar:
# 1. **Qisqa muddat (1-3 oy):** _______________
# 2. **O'rta muddat (3-6 oy):** _______________
# 3. **Uzoq muddat (6-12 oy):** _______________
#
# #### 🎯 KPI monitoring:
# Kuzatib borish kerak bo'lgan asosiy ko'rsatkichlar:
# 1. _______________
# 2. _______________
# 3. _______________
#
# #### 🚨 Risk faktorlari:
# E'tibor qaratish kerak bo'lgan muammolar:
# 1. _______________
# 2. _______________
# 3. _______________

# %% [markdown]
# ---
#
# ## 📋 Baholash jadvali
#
# ### 💯 Ball taqsimoti:
#
# | Bo'lim | Vazifalar | Maksimal ball | Olingan ball |
# |--------|-----------|---------------|---------------|
# | 1. Tizimga ulanish | 1.1-1.2 | 10 | ___/10 |
# | 2. COUNT funksiyasi | 2.1-2.3 | 15 | ___/15 |
# | 3. SUM va AVG | 3.1-3.3 | 20 | ___/20 |
# | 4. GROUP BY, HAVING | 4.1-4.3 | 25 | ___/25 |
# | 5. Murakkab SQL | 5.1-5.3 | 20 | ___/20 |
# | 6. Vizualizatsiya | 6.1-6.2 | 10 | ___/10 |
# | **JAMI** | | **100** | **___/100** |
#
# ### 🎖️ Qo'shimcha balllar:
# - **Kreativlik va innovatsiya:** +3 ball
# - **Amaliy qiymat:** +3 ball
# - **Kodni optimize qilish:** +2 ball
# - **Qo'shimcha tahlillar:** +2 ball
#
# ### 📊 Baholar:
# - **A (85-100 ball):** Juda yaxshi - Barcha talablar to'liq bajarilgan
# - **B (70-84 ball):** Yaxshi - Asosiy talablar bajarilgan
# - **C (55-69 ball):** Qoniqarli - Ba'zi kamchiliklar bor
# - **D (40-54 ball):** Qoniqarsiz - Ko'plab kamchiliklar
# - **F (0-39 ball):** Muvaffaqiyatsiz - Takror topshirish zarur
#
# ---
#
# ## ✅ Tekshirish ro'yxati
#
# **Topshirishdan oldin quyidagilarni tekshiring:**
#
# - [ ] Barcha kod bloklari ishga tushadi
# - [ ] SQL so'rovlar sintaksis jihatdan to'g'ri
# - [ ] Natijalar mantiqan to'g'ri
# - [ ] Grafiklar aniq va tushunarli
# - [ ] Xulosalar yozilgan
# - [ ] Tavsiyalar amaliy
# - [ ] Talaba ma'lumotlari to'ldirilgan
# - [ ] Notebook to'liq saqlangan
#
# ---
#
# ## 📚 Qo'shimcha resurslar
#
# Qiyinchilik tug'ilsa, quyidagi resurslarga murojaat qiling:
#
# 1. **PostgreSQL Documentation:** https://www.postgresql.org/docs/
# 2. **SQL Tutorial:** https://www.w3schools.com/sql/
# 3. **Pandas Documentation:** https://pandas.pydata.org/docs/
# 4. **Matplotlib Gallery:** https://matplotlib.org/stable/gallery/
# 5. **Seaborn Tutorial:** https://seaborn.pydata.org/tutorial.html
#
# ---
#
# **📧 Savollar bo'lsa:** ________ elektron pochtasiga murojaat qiling
#
# **🕐 Topshirish muddati:** ________ gacha
#
# **📁 Topshirish formati:** `.ipynb` fayl
#
# ---
#
# 🎯 **Omad tilaymiz! PostgreSQL agregatsiya va guruhlash bo'yicha bilimlaringizni namoyish eting!**
