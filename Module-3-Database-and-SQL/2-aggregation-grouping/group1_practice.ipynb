# %% [markdown]
# # 👥 Guruh 1 - Amaliy Mashg'ulot
# ## PostgreSQL Agregatsiya va Guruhlash
#
# ### 🎯 Guruh vazifasi: E-commerce Platform tahlili
#
# **Guruh a'zolari:** _(ismlaringizni yozing)_
# 1. ________________
# 2. ________________
# 3. ________________
# 4. ________________
#
# ### 📋 Vazifa: Online do'kon uchun biznes-tahlil hisoboti tayyorlash
#
# **Scenariy:** Siz "TechMart" online do'konining ma'lumotlar tahlili guruhisiz. Kompaniya rahbariyati sizdan quyidagi savollarга javob berishni so'raydi:
#
# 1. **Mijozlar tahlili** - Eng qimmat mijozlar kimlar?
# 2. **Mahsulot strategiyasi** - Qaysi kategoriyalar eng foydali?
# 3. **Xodimlar samaradorligi** - Eng yaxshi sotuvchilar?
# 4. **Geografik tahlil** - Qaysi hududlarda kengayish kerak?
# 5. **Vaqt tahlili** - Qaysi oylar eng yaxshi?
#
# ---

# %% [markdown]
# ## 🔌 Tizimga kirish

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Grafik sozlamalari
plt.style.use('seaborn-v0_8')
sns.set_palette("Set2")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 10

print("✅ Kutubxonalar yuklandi!")
print("👥 Guruh 1 - TechMart tahlili boshlandi!")

# %%
# PostgreSQL ulanish
connection_params = {
    'host': 'localhost',
    'database': 'lesson_aggregation',
    'user': 'data_scientist',
    'password': 'secure_password123',
    'port': '5432'
}

engine = create_engine(f"postgresql://{connection_params['user']}:{connection_params['password']}@"
                      f"{connection_params['host']}:{connection_params['port']}/{connection_params['database']}")

print("🔗 PostgreSQL ga ulandi!")
print("📊 TechMart ma'lumotlar bazasi tayyor!")

# %% [markdown]
# ## 1️⃣ Mijozlar Tahlili (25 ball)
#
# ### 🎯 Vazifa: Eng qimmatbaho mijozlarni aniqlash
#
# **Talablar:**
# - TOP 10 mijozni aniqlang (eng ko'p xarid qilgan)
# - Ularning demografik ma'lumotlarini ko'rsating
# - Har birining o'rtacha buyurtma qiymatini hisoblang
# - VIP mijozlar uchun tavsiyalar bering

# %%
# 🔍 TOP 10 mijozlar tahlili
# TODO: Guruh a'zolari birgalikda so'rov yozing

top_customers_query = """
-- Guruh 1 ning yechimi:
-- Quyidagi ma'lumotlarni chiqaring:
-- - Mijoz ismi va familiyasi
-- - Hududi va turi  
-- - Jami buyurtmalar soni
-- - Jami sarflagan puli
-- - O'rtacha buyurtma qiymati
-- - Birinchi va oxirgi xarid sanasi


"""

# Guruh javobini bu yerga yozing:
top_customers = pd.read_sql(top_customers_query, engine)
print("👑 TOP 10 MIJOZLAR:")
print(top_customers.to_string(index=False))

# %%
# 📊 Mijozlar vizualizatsiyasi
# TODO: Guruh a'zolari grafik yaratsin

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# 1. TOP mijozlar bo'yicha sarflangan pul
# Guruh vazifasi: Bar chart yarating

# 2. Mijoz turlari bo'yicha taqsimot  
# Guruh vazifasi: Pie chart yarating

# 3. Hududlar bo'yicha VIP mijozlar
# Guruh vazifasi: Horizontal bar chart

# 4. O'rtacha buyurtma qiymati vs Buyurtmalar soni
# Guruh vazifasi: Scatter plot

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📝 Guruh xulosasi - Mijozlar tahlili:
#
# **Guruh a'zolari bu bo'limni to'ldiring:**
#
# 1. **Eng qimmatbaho mijoz:** ________________
# 2. **Asosiy mijoz turi:** ________________
# 3. **Eng foydali hudud:** ________________
# 4. **VIP mijozlar uchun tavsiya:** ________________
#
# ---

# %% [markdown]
# ## 2️⃣ Mahsulot Strategiyasi Tahlili (25 ball)
#
# ### 🎯 Vazifa: Eng foydali kategoriya va mahsulotlarni aniqlash
#
# **Talablar:**
# - Kategoriyalar bo'yicha daromad va foyda
# - Har bir kategoriyaning bozor ulushi
# - Eng ko'p sotilgan mahsulotlar
# - Qaysi mahsulotlar kamroq sotilmoqda

# %%
# 🛍️ Kategoriyalar tahlili
# TODO: Guruh a'zolari kategoriyalar bo'yicha to'liq tahlil qilsin

category_analysis_query = """
-- Guruh 1 ning kategoriya tahlili:
-- Quyidagilarni hisoblang:
-- - Har bir kategoriyadan sotilgan mahsulotlar soni
-- - Jami daromad va foyda
-- - Foyda foizi
-- - Bozor ulushi (daromad bo'yicha)
-- - O'rtacha mahsulot narxi
-- - O'rtacha reyting


"""

category_analysis = pd.read_sql(category_analysis_query, engine)
print("📊 KATEGORIYALAR TAHLILI:")
print(category_analysis.to_string(index=False))

# %%
# 🏆 TOP va FLOP mahsulotlar
# TODO: Eng yaxshi va eng yomon mahsulotlarni aniqlang

# TOP 5 mahsulotlar (daromad bo'yicha)
top_products_query = """
-- Guruh vazifasi: TOP 5 mahsulotlar

"""

# FLOP 5 mahsulotlar (kam sotilgan)
flop_products_query = """
-- Guruh vazifasi: Kam sotilgan mahsulotlar

"""

top_products = pd.read_sql(top_products_query, engine)
flop_products = pd.read_sql(flop_products_query, engine)

print("🏆 TOP 5 MAHSULOTLAR:")
print(top_products.to_string(index=False))

print("\n📉 KAM SOTILGAN MAHSULOTLAR:")
print(flop_products.to_string(index=False))

# %% [markdown]
# ### 📝 Guruh xulosasi - Mahsulot strategiyasi:
#
# **Guruh a'zolari bu bo'limni to'ldiring:**
#
# 1. **Eng foydali kategoriya:** ________________
# 2. **Eng ko'p foyda beruvchi mahsulot:** ________________
# 3. **Qaysi kategoriyani rivojlantirish kerak:** ________________
# 4. **Kam sotilgan mahsulotlar uchun tavsiya:** ________________
#
# ---

# %% [markdown]
# ## 3️⃣ Xodimlar Samaradorligi (25 ball)
#
# ### 🎯 Vazifa: Eng samarali xodimlar va bo'limlarni aniqlash
#
# **Talablar:**
# - Bo'limlar bo'yicha samaradorlik
# - Xodim boshiga savdo
# - Maosh va daromad nisbati
# - Stimul tizimi uchun tavsiyalar

# %%
# 👨‍💼 Bo'limlar samaradorligi
# TODO: Guruh a'zolari bo'limlar tahlilini qilsin

department_efficiency_query = """
-- Guruh vazifasi: Bo'limlar samaradorligi
-- Quyidagilarni hisoblang:
-- - Har bo'limdagi xodimlar soni
-- - Jami maosh xarajati
-- - Jami savdo daromadi
-- - Xodim boshiga o'rtacha savdo
-- - ROI (Return on Investment)
-- - Samaradorlik koeffitsienti


"""

dept_efficiency = pd.read_sql(department_efficiency_query, engine)
print("🏢 BO'LIMLAR SAMARADORLIGI:")
print(dept_efficiency.to_string(index=False))

# %%
# ⭐ TOP xodimlar (individual)
# TODO: Eng yaxshi individual xodimlarni aniqlang

top_employees_query = """
-- Guruh vazifasi: Individual xodimlar tahlili
-- Quyidagilarni ko'rsating:
-- - Xodim ismi va bo'limi
-- - Qayta ishlagan buyurtmalar soni
-- - Umumiy savdo summasi
-- - Oylik maoshi
-- - Samaradorlik koeffitsienti
-- - Faqat 10+ buyurtma qabul qilganlar


"""

top_employees = pd.read_sql(top_employees_query, engine)
print("⭐ TOP XODIMLAR:")
print(top_employees.to_string(index=False))

# %% [markdown]
# ### 📝 Guruh xulosasi - Xodimlar samaradorligi:
#
# **Guruh a'zolari bu bo'limni to'ldiring:**
#
# 1. **Eng samarali bo'lim:** ________________
# 2. **Eng yaxshi sotuvchi:** ________________
# 3. **Qaysi bo'limni kuchaytirish kerak:** ________________
# 4. **Stimul tizimi tavsiyasi:** ________________
#
# ---

# %% [markdown]
# ## 4️⃣ Yakuniy Prezentatsiya (25 ball)
#
# ### 🎯 Vazifa: Rahbariyat uchun hisobot tayyorlash
#
# **Talablar:**
# - Barcha tahlillarni umumlashtirish
# - Asosiy xulosalar
# - Amaliy tavsiyalar
# - Vizual dashboard yaratish

# %%
# 📊 Executive Dashboard
# TODO: Guruh a'zolari rahbariyat uchun dashboard yaratsin

print("🎯 TECHMART - EXECUTIVE DASHBOARD")
print("=" * 50)

# Umumiy ko'rsatkichlar
summary_query = """
-- Guruh vazifasi: Umumiy biznes ko'rsatkichlari
-- Quyidagilarni hisoblang:
-- - Jami mijozlar soni
-- - Faol mijozlar foizi
-- - Jami buyurtmalar soni
-- - Umumiy daromad
-- - O'rtacha buyurtma qiymati
-- - Jami foyda
-- - Foyda foizi


"""

summary = pd.read_sql(summary_query, engine)
print("💰 ASOSIY KO'RSATKICHLAR:")
print(summary.to_string(index=False))

# %%
# 📈 Vizual Dashboard
# TODO: Guruh a'zolari 6 ta grafik yaratsin

fig = plt.figure(figsize=(18, 15))

# 1. Oylik daromad tendentsiyasi
ax1 = plt.subplot(3, 3, 1)
# Guruh vazifasi: Line chart

# 2. Kategoriyalar bo'yicha daromad
ax2 = plt.subplot(3, 3, 2)
# Guruh vazifasi: Bar chart

# 3. Hududlar bo'yicha mijozlar
ax3 = plt.subplot(3, 3, 3)
# Guruh vazifasi: Pie chart

# 4. Bo'limlar samaradorligi
ax4 = plt.subplot(3, 3, 4)
# Guruh vazifasi: Horizontal bar chart

# 5. Mijoz turlari bo'yicha o'rtacha xarid
ax5 = plt.subplot(3, 3, 5)
# Guruh vazifasi: Bar chart

# 6. TOP mahsulotlar reyting vs sotuvlar
ax6 = plt.subplot(3, 3, 6)
# Guruh vazifasi: Scatter plot

# 7. Xodimlar yoshi vs samaradorlik
ax7 = plt.subplot(3, 3, 7)
# Guruh vazifasi: Scatter plot

# 8. Kategoriyalar foyda foizi
ax8 = plt.subplot(3, 3, 8)
# Guruh vazifasi: Donut chart

# 9. Umumiy statistika
ax9 = plt.subplot(3, 3, 9)
# Guruh vazifasi: KPI ko'rsatkichlari

plt.suptitle('TechMart - Executive Dashboard', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📋 Yakuniy Hisobot
#
# ### 🏆 Guruh 1 ning TechMart uchun Strategik Tavsiyalari:
#
# **Guruh a'zolari quyidagi bo'limlarni to'ldiring:**
#
# #### 1. 👥 Mijozlar strategiyasi:
# - **Asosiy topilma:** ________________
# - **VIP mijozlar uchun maxsus takliflar:** ________________
# - **Yangi mijozlarni jalb qilish:** ________________
#
# #### 2. 🛍️ Mahsulot strategiyasi:
# - **Rivojlantirish kerak bo'lgan kategoriya:** ________________
# - **Kamroq sotilgan mahsulotlar uchun reja:** ________________
# - **Yangi mahsulot takliflari:** ________________
#
# #### 3. 👨‍💼 Xodimlar strategiyasi:
# - **Eng samarali bo'lim:** ________________
# - **Takomillashtirish kerak bo'lgan bo'lim:** ________________
# - **Rag'batlantirish tizimi:** ________________
#
# #### 4. 🌍 Geografik strategiya:
# - **Kengayish uchun istiqbolli hududlar:** ________________
# - **Logistika optimizatsiyasi:** ________________
# - **Mahalliy marketing strategiyasi:** ________________
#
# #### 5. 📈 Yakuniy tavsiyalar:
# 1. **Qisqa muddatli (1-3 oy):** ________________
# 2. **O'rta muddatli (3-6 oy):** ________________
# 3. **Uzoq muddatli (6-12 oy):** ________________
#
# ---
#
# ### 💯 Guruh baholash mezoni:
#
# | Mezon | Ball | Guruh o'z-o'zini baholashi |
# |-------|------|----------------------------|
# | SQL so'rovlarining to'g'riligi | 25 | ___ / 25 |
# | Ma'lumotlar tahlilining chuqurligi | 25 | ___ / 25 |
# | Vizualizatsiya sifati | 25 | ___ / 25 |
# | Amaliy tavsiyalar | 25 | ___ / 25 |
# | **JAMI** | **100** | **___ / 100** |
#
# **Guruh rahbari imzosi:** ________________
# **Sana:** ________________
#
# ---
#
# 🎉 **Tabriklaymiz! Guruh 1 TechMart tahlilini muvaffaqiyatli yakunladi!**
