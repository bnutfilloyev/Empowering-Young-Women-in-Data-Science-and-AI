# %% [markdown]
# # 🛠️ Amaliy Mashq: AI va Data Science bilan Tanishish
#
# **Maqsad:** Ma'ruza materiallarini amaliy jihatdan mustahkamlash
#
# ---

# %% [markdown]
# ## 🎯 Mashq 1: AI Tarixi Timeline
#
# Quyidagi AI tarixidagi muhim voqealarni to'g'ri yil bilan moslashtiring:

# %%
# AI tarixi bo'yicha interaktiv test

# Voqealar ro'yxati
events = [
    "Turing Test yaratildi",
    "Birinchi neural network ishlab chiqildi", 
    "'Artificial Intelligence' atamasi paydo bo'ldi",
    "Deep Blue shaxmatda G.Kasparovni mag'lub etdi",
    "ImageNet competition'da AI inson darajasiga yetdi",
    "ChatGPT chiqarildi"
]

# Yillar ro'yxati
years = [1950, 1956, 1943, 1997, 2012, 2022]

print("🎯 AI TARIXI TIMELINE TESTI")
print("="*35)
print("Quyidagi voqealarni to'g'ri yil bilan moslashtiring:\n")

for i, event in enumerate(events, 1):
    print(f"{i}. {event}")

print("\nYillar:", years)
print("\n💡 Javoblaringizni yozing (masalan: 1-1950, 2-1943, ...)")

# TODO: O'z javoblaringizni shu yerga yozing
# Javoblar:
# 1. Turing Test yaratildi - ?
# 2. Birinchi neural network - ?
# 3. 'AI' atamasi - ?
# 4. Deep Blue - ?
# 5. ImageNet - ?
# 6. ChatGPT - ?
# Out:
# 🎯 AI TARIXI TIMELINE TESTI
# ...
# Quyidagi voqealarni to'g'ri yil bilan moslashtiring:
#
# 1. Turing Test yaratildi
# 2. Birinchi neural network ishlab chiqildi
# 3. 'Artificial Intelligence' atamasi paydo bo'ldi
# 4. Deep Blue shaxmatda G.Kasparovni mag'lub etdi
# 5. ImageNet competition'da AI inson darajasiga yetdi
# 6. ChatGPT chiqarildi
#
# Yillar: [1950, 1956, 1943, 1997, 2012, 2022]
#
# 💡 Javoblaringizni yozing (masalan: 1-1950, 2-1943, ...)

# %%
a = 5
b = 4

# %%
a + b
# Out:
# 9

# %% [markdown]
# ## 📊 Mashq 2: CRISP-DM Loyiha Rejasi
#
# Quyidagi real hayotiy muammo uchun CRISP-DM jarayonini qo'llaymiz:

# %% [markdown]
# ### 🏪 Vaziyat: Online Do'kon Mijozlari
#
# **Kompaniya:** "TechMart" - elektronika sotuvchi online do'kon
#
# **Muammo:** So'nggi 6 oyda mijozlar sotib olish darajasi 30% ga kamaydi. Kompaniya rahbariyati sababini bilmoqchi va yechim topishni xohlaydi.
#
# **Mavjud ma'lumotlar:**
# - Mijozlar ma'lumotlari (yosh, jins, joylashuv)
# - Sotib olish tarixi (mahsulot, narx, sana)
# - Website faoliyati (sahifalar, vaqt, tark etish)
# - Mijozlar sharhlari va reyting
# - Marketing kampaniyalari ma'lumotlari

# %%
# CRISP-DM jarayonini qo'llaymiz

print("🔄 CRISP-DM LOYIHA REJASI")
print("="*30)

# TODO: Har bir bosqich uchun javob bering

print("\n1️⃣ BIZNES TUSHUNISH")
print("-" * 20)
# Savollar:
# - Aniq maqsad nima?
# - Muvaffaqiyat qanday o'lchanadi?
# - Qanday yechim kutilmoqda?

business_goal = """TODO: Shu yerga yozing:
Maqsad: 
Muvaffaqiyat mezoni: 
Kutilayotgan natija: 
"""

print("\n2️⃣ MA'LUMOTLARNI TUSHUNISH")
print("-" * 25)
# Savollar:
# - Qanday ma'lumotlar mavjud?
# - Ma'lumotlar sifati qanday?
# - Etishmayotgan ma'lumotlar bormi?

data_understanding = """TODO: Shu yerga yozing:
Mavjud ma'lumotlar: 
Ma'lumotlar hajmi: 
Sifat muammolari: 
Qo'shimcha ma'lumotlar: 
"""

print("\n3️⃣ MA'LUMOTLARNI TAYYORLASH")
print("-" * 25)
# Savollar:
# - Qanday tozalash kerak?
# - Yangi feature'lar yaratish mumkinmi?
# - Qanday o'zgartirish kerak?

data_preparation = """TODO: Shu yerga yozing:
Tozalash ishlar: 
Yangi xususiyatlar: 
Transformation: 
"""

print("\n4️⃣ MODELLASHTIRISH")
print("-" * 15)
# Savollar:
# - Qanday model turi kerak?
# - Classification, regression, clustering?
# - Qanday algoritmlar sinab ko'rish mumkin?

modeling = """TODO: Shu yerga yozing:
Model turi: 
Algoritmlar: 
Target variable: 
"""

print("\n5️⃣ BAHOLASH")
print("-" * 10)
# Savollar:
# - Qanday metrika ishlatish?
# - Model yetarli darajadami?
# - Biznes maqsadiga mos keladimi?

evaluation = """TODO: Shu yerga yozing:
Baholash metrikasi: 
Muvaffaqiyat chegarasi: 
Biznes ta'siri: 
"""

print("\n6️⃣ DEPLOYMENT")
print("-" * 12)
# Savollar:
# - Model qanday ishlatiladi?
# - Kim foydalanadi?
# - Qanday monitoring kerak?

deployment = """TODO: Shu yerga yozing:
Implementation: 
Foydalanuvchilar: 
Monitoring rejasi: 
"""
# Out:
# 🔄 CRISP-DM LOYIHA REJASI
# ...
#
# 1️⃣ BIZNES TUSHUNISH
# --------------------
#
# 2️⃣ MA'LUMOTLARNI TUSHUNISH
# -------------------------
#
# 3️⃣ MA'LUMOTLARNI TAYYORLASH
# -------------------------
#
# 4️⃣ MODELLASHTIRISH
# ---------------
#
# 5️⃣ BAHOLASH
# ----------
#
# 6️⃣ DEPLOYMENT
# ------------

# %% [markdown]
# ## 🌍 Mashq 3: AI Qo'llash Sohalari
#
# Har bir soha uchun AI qo'llanilishiga misol keltiring:

# %%
# AI qo'llash sohalari

print("🌍 AI QO'LLASH SOHALARI")
print("="*25)

areas = {
    "🏥 Tibbiyot": {
        "AI qo'llanishi": "TODO: Misol keltiring",
        "Foyda": "TODO: Qanday yordam beradi?",
        "Real misol": "TODO: Kompaniya yoki mahsulot nomi"
    },
    "🎓 Ta'lim": {
        "AI qo'llanishi": "TODO: Misol keltiring",
        "Foyda": "TODO: Qanday yordam beradi?",
        "Real misol": "TODO: Kompaniya yoki mahsulot nomi"
    },
    "💼 Biznes": {
        "AI qo'llanishi": "TODO: Misol keltiring",
        "Foyda": "TODO: Qanday yordam beradi?",
        "Real misol": "TODO: Kompaniya yoki mahsulot nomi"
    },
    "🚗 Transport": {
        "AI qo'llanishi": "TODO: Misol keltiring",
        "Foyda": "TODO: Qanday yordam beradi?",
        "Real misol": "TODO: Kompaniya yoki mahsulot nomi"
    },
    "🌱 Atrof-muhit": {
        "AI qo'llanishi": "TODO: Misol keltiring",
        "Foyda": "TODO: Qanday yordam beradi?",
        "Real misol": "TODO: Kompaniya yoki mahsulot nomi"
    }
}

# TODO: Yuqoridagi dictionary'ni to'ldiring
for area, details in areas.items():
    print(f"\n{area}:")
    for key, value in details.items():
        print(f"  {key}: {value}")
# Out:
# 🌍 AI QO'LLASH SOHALARI
# ...
#
# 🏥 Tibbiyot:
#   AI qo'llanishi: TODO: Misol keltiring
#   Foyda: TODO: Qanday yordam beradi?
#   Real misol: TODO: Kompaniya yoki mahsulot nomi
#
# 🎓 Ta'lim:
#   AI qo'llanishi: TODO: Misol keltiring
#   Foyda: TODO: Qanday yordam beradi?
#   Real misol: TODO: Kompaniya yoki mahsulot nomi
#
# 💼 Biznes:
#   AI qo'llanishi: TODO: Misol keltiring
#   Foyda: TODO: Qanday yordam beradi?
#   Real misol: TODO: Kompaniya yoki mahsulot nomi
#
# 🚗 Transport:
#   AI qo'llanishi: TODO: Misol keltiring
#   Foyda: TODO: Qanday yordam beradi?
#   Real misol: TODO: Kompaniya yoki mahsulot nomi
#
# 🌱 Atrof-muhit:
#   AI qo'llanishi: TODO: Misol keltiring
#   Foyda: TODO: Qanday yordam beradi?
#   Real misol: TODO: Kompaniya yoki mahsulot nomi

# %% [markdown]
# ## 💡 Bonus Mashq: Shaxsiy AI G'oya
#
# Ma'ruzada guruh ishi sifatida loyiha g'oyasini ishlab chiqdingiz. Endi individual ravishda o'z g'oyangizni rivojlantiring:

# %%
# Shaxsiy AI loyiha g'oyasi

print("💡 SHAXSIY AI LOYIHA G'OYASI")
print("="*30)

# TODO: Quyidagi ma'lumotlarni to'ldiring

project_idea = {
    "Loyiha nomi": "TODO: Qisqa va tushunarli nom",
    
    "Muammo": """TODO: Qanday muammo hal qilinmoqda?
    - Kim bu muammodan aziyat chekmoqda?
    - Muammo qanchalik muhim?
    """,
    
    "AI yechimi": """TODO: AI qanday yordam beradi?
    - Qanday AI texnologiyasi (ML, NLP, Computer Vision)?
    - Qanday natija kutilmoqda?
    """,
    
    "Ma'lumotlar": """TODO: Qanday ma'lumotlar kerak?
    - Ma'lumotlar qayerdan olinadi?
    - Qancha ma'lumot kerak?
    """,
    
    "Foydalanuvchilar": """TODO: Kim foydalanadi?
    - Maqsadli auditoriya kimlar?
    - Qanday platformada (web, mobile, desktop)?
    """,
    
    "Ta'sir": """TODO: Qanday ijobiy ta'sir?
    - Qanchaga odamga foyda?
    - Jamiyatga qanday ta'sir?
    """,
    
    "Qiyinchiliklar": """TODO: Qanday qiyinchiliklar bo'lishi mumkin?
    - Texnik muammolar?
    - Ma'lumotlar muammolari?
    """,
    
    "Keyingi qadamlar": """TODO: Loyihani qanday boshlash mumkin?
    - Birinchi qadam nima?
    - Qanday resurslar kerak?
    """
}

# Ma'lumotlarni chop etish
for key, value in project_idea.items():
    print(f"\n📋 {key}:")
    print(f"   {value}")

print("\n" + "="*50)
print("💪 Bu g'oyani assignment.md da yanada rivojlantiring!")

# %% [markdown]
# ## ✅ Mashq Yakuniy Xulosa
#
# ### Bugun amaliyotda o'rgandik:
#
# 1. **AI tarixi** - muhim voqealar va ular yillari
# 2. **CRISP-DM** - real loyiha rejasini tuzish
# 3. **AI qo'llash** - har xil sohalarda amaliy foydalanish
# 4. **Loyiha yaratish** - o'z g'oyani rivojlantirish
#
# ### 📝 Keyingi qadamlar:
#
# 1. **assignment.md** dagi vazifalarni bajaring
# 2. O'z loyiha g'oyangizni yanada rivojlantiring
# 3. Keyingi darsga (Python va muhit sozlash) tayyorlaning
# 4. AI/Data Science haqida qo'shimcha o'qing
#
# ---
#
# **🎯 Eslatma:** Barcha TODO qismlarini to'ldiring va natijalarni saqlang!
