# %% [markdown]
# # Amaliy Mashg'ulot: Data Tozalash va Tayyorlash
#
# ## 🎯 Maqsad
# Bu amaliy mashg'ulotda siz real ma'lumotlar to'plami bilan ishlaysiz va barcha o'rgangan usullaringizni qo'llaysiz.
#
# ## 📚 Vazifalar
# 1. Ma'lumotlarni yuklash va o'rganish
# 2. Missing values bilan ishlash
# 3. Takroriy ma'lumotlarni tozalash
# 4. Kategorik ma'lumotlarni encoding qilish
# 5. Ma'lumotlarni ML uchun tayyorlash

# %% [markdown]
# ## 📦 Kutubxonalarni Yuklash

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

pd.set_option('display.max_columns', None)
print("✅ Kutubxonalar yuklandi!")

# %% [markdown]
# ---
# ## Vazifa 1: Ma'lumotlarni Yaratish va O'rganish
#
# Keling, onlayn magazin uchun mijozlar ma'lumotlarini yarataylik.

# %%
# Mijozlar ma'lumotlari
np.random.seed(42)

data = {
    'Mijoz_ID': range(1, 21),
    'Ism': ['Ali', 'Vali', 'Sardor', 'Malika', 'Nigora', 'Aziz', 'Dildora', 'Jasur',
            'Zarina', 'Kamol', 'Shoira', 'Anvar', 'Gulnora', 'Bobur', 'Madina',
            'Ali', 'Olim', 'Sevara', 'Davron', 'Vali'],
    'Yosh': [25, 30, np.nan, 28, 35, np.nan, 27, 32, 29, np.nan, 
             26, 31, np.nan, 33, 28, 25, 29, np.nan, 30, 30],
    'Jins': ['Erkak', 'Erkak', 'Erkak', 'Ayol', 'Ayol', 'Erkak', 'Ayol', 'Erkak',
             'Ayol', 'Erkak', 'Ayol', 'Erkak', 'Ayol', 'Erkak', 'Ayol',
             'Erkak', 'Erkak', 'Ayol', 'Erkak', 'Erkak'],
    'Shahar': ['Toshkent', 'Samarqand', 'Buxoro', 'Toshkent', np.nan, 'Toshkent', 
               'Samarqand', np.nan, 'Toshkent', 'Buxoro', 'Farg\'ona', 'Toshkent',
               np.nan, 'Samarqand', 'Toshkent', 'Toshkent', 'Buxoro', 'Farg\'ona',
               'Toshkent', 'Samarqand'],
    'Daromad_Darajasi': ['O\'rta', 'Yuqori', 'Past', 'Yuqori', 'O\'rta', np.nan, 
                          'Yuqori', 'O\'rta', 'Yuqori', 'Past', 'O\'rta', 'Yuqori',
                          np.nan, 'O\'rta', 'Yuqori', 'O\'rta', 'Past', 'O\'rta', 
                          'Yuqori', 'Yuqori'],
    'Xarid_Soni': [12, np.nan, 5, 23, np.nan, 15, 28, 7, 19, 3,
                   14, 21, np.nan, 11, 25, 12, 8, 16, np.nan, 20],
    'Jami_Xarajat': [1500000, np.nan, 450000, 3200000, np.nan, 1800000, 4100000, 
                     680000, 2700000, 350000, 1900000, 2900000, np.nan, 1600000, 
                     3500000, 1500000, 720000, 2100000, np.nan, 2800000]
}

df = pd.DataFrame(data)
print("📊 MIJOZLAR MA'LUMOTLARI")
print(df)

# %% [markdown]
# ### 📝 Topshiriq 1.1: Ma'lumotlarni O'rganish
#
# Quyidagi savolarga javob bering:

# %%
# TODO: DataFrame haqida asosiy ma'lumot (shape, dtypes, info)
print("DataFrame o'lchami:")
# Sizning kodingiz

print("\nData types:")
# Sizning kodingiz

print("\nAsosiy ma'lumot:")
# Sizning kodingiz

# %%
# TODO: Statistik ma'lumotlar (describe)
# Sizning kodingiz

# %% [markdown]
# ---
# ## Vazifa 2: Missing Values Tahlili
#
# ### 📝 Topshiriq 2.1: Missing Values ni Aniqlash

# %%
# TODO: Har bir ustundagi missing values sonini toping
# Sizning kodingiz

# %%
# TODO: Missing values foizini hisoblang
# Sizning kodingiz

# %%
# TODO: Missing values ni vizualizatsiya qiling (heatmap)
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 2.2: Missing Values ni To'ldirish
#
# **Strategiya:**
# - `Yosh` - median bilan
# - `Shahar` - mode bilan
# - `Daromad_Darajasi` - mode bilan
# - `Xarid_Soni` - median bilan
# - `Jami_Xarajat` - median bilan

# %%
# TODO: df nusxasini yarating
df_cleaned = df.copy()

# TODO: Yosh - median
# Sizning kodingiz

# TODO: Shahar - mode
# Sizning kodingiz

# TODO: Daromad_Darajasi - mode
# Sizning kodingiz

# TODO: Xarid_Soni - median
# Sizning kodingiz

# TODO: Jami_Xarajat - median
# Sizning kodingiz

print("✅ Missing values to'ldirildi")
print(f"Qolgan missing values: {df_cleaned.isnull().sum().sum()}")

# %%
# TODO: To'ldirilgan ma'lumotlarni ko'ring
# Sizning kodingiz

# %% [markdown]
# ---
# ## Vazifa 3: Takroriy Ma'lumotlarni Tozalash
#
# ### 📝 Topshiriq 3.1: Takrorlarni Aniqlash

# %%
# TODO: Takroriy qatorlarni aniqlang (Mijoz_ID dan tashqari)
# Sizning kodingiz

# %%
# TODO: Takroriy qatorlarni ko'rsating
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 3.2: Takrorlarni O'chirish

# %%
# TODO: Takroriy qatorlarni o'chiring (Mijoz_ID dan tashqari, birinchisini saqlang)
# Sizning kodingiz

print(f"O'lcham: {len(df_cleaned)} → {len(df_cleaned)} qator")

# %% [markdown]
# ---
# ## Vazifa 4: Kategorik Ma'lumotlarni Encoding
#
# ### 📝 Topshiriq 4.1: Jins - Label Encoding

# %%
# TODO: Jins ustunini label encoding qiling (Erkak=0, Ayol=1)
# Sizning kodingiz

print("✅ Jins encoded")
print(df_cleaned[['Jins']].head())

# %% [markdown]
# ### 📝 Topshiriq 4.2: Daromad_Darajasi - Ordinal Encoding

# %%
# TODO: Daromad_Darajasi ni ordinal encoding qiling (Past=0, O'rta=1, Yuqori=2)
# Sizning kodingiz

print("✅ Daromad_Darajasi encoded")
print(df_cleaned[['Daromad_Darajasi']].head())

# %% [markdown]
# ### 📝 Topshiriq 4.3: Shahar - One-Hot Encoding

# %%
# TODO: Shahar ustunini one-hot encoding qiling (drop_first=True)
# Sizning kodingiz

print("✅ Shahar encoded")
print(df_cleaned.head())

# %% [markdown]
# ---
# ## Vazifa 5: Ma'lumotlarni ML uchun Tayyorlash
#
# ### 📝 Topshiriq 5.1: Kerakli Ustunlarni Tanlash

# %%
# TODO: Ism va Mijoz_ID ustunlarini o'chiring
# Sizning kodingiz

print("✅ Keraksiz ustunlar o'chirildi")
print(df_cleaned.head())

# %% [markdown]
# ### 📝 Topshiriq 5.2: Ma'lumotlar Tayyorligini Tekshirish

# %%
# TODO: Yakuniy ma'lumotlar haqida ma'lumot
print("📊 YAKUNIY MA'LUMOTLAR")
print(f"O'lcham: {df_cleaned.shape}")
print(f"Missing values: {df_cleaned.isnull().sum().sum()}")
print(f"Duplicates: {df_cleaned.duplicated().sum()}")
print(f"\nData types:")
print(df_cleaned.dtypes)

# %%
# TODO: Barcha ustunlar raqamli ekanligini tekshiring
numeric_cols = df_cleaned.select_dtypes(include=[np.number]).shape[1]
total_cols = len(df_cleaned.columns)

print(f"✅ Raqamli ustunlar: {numeric_cols}/{total_cols}")
if numeric_cols == total_cols:
    print("🎉 Barcha ustunlar raqamli! ML uchun tayyor!")
else:
    print("⚠️ Ba'zi ustunlar hali kategorik!")

# %% [markdown]
# ---
# ## Vazifa 6: Vizualizatsiya va Tahlil
#
# ### 📝 Topshiriq 6.1: Boshlang'ich vs Yakuniy Taqqoslash

# %%
# TODO: Boshlang'ich va yakuniy ma'lumotlarni taqqoslang
comparison = pd.DataFrame({
    'Metric': ['Qatorlar', 'Ustunlar', 'Missing Values', 'Duplicates'],
    'Boshlang\'ich': [
        len(df),
        len(df.columns),
        df.isnull().sum().sum(),
        df.duplicated().sum()
    ],
    'Yakuniy': [
        len(df_cleaned),
        len(df_cleaned.columns),
        df_cleaned.isnull().sum().sum(),
        df_cleaned.duplicated().sum()
    ]
})

print(comparison.to_string(index=False))

# %% [markdown]
# ### 📝 Topshiriq 6.2: Ma'lumotlar Taqsimoti

# %%
# TODO: Raqamli ustunlar uchun histogramma chizing
# Sizning kodingiz

# %%
# TODO: Correlation matrix yarating
# Sizning kodingiz

# %% [markdown]
# ---
# ## 🎯 Qo'shimcha Topshiriqlar (Ixtiyoriy)
#
# ### Topshiriq A: SimpleImputer Ishlatish

# %%
# TODO: Asl ma'lumotlar bilan SimpleImputer dan foydalanib missing values ni to'ldiring
# Sizning kodingiz

# %% [markdown]
# ### Topshiriq B: Feature Engineering

# %%
# TODO: Yangi feature yarating: O'rtacha_Xarid = Jami_Xarajat / Xarid_Soni
# Sizning kodingiz

# %% [markdown]
# ### Topshiriq C: Outlier Detection

# %%
# TODO: Jami_Xarajat ustunida outlier borligini tekshiring (boxplot)
# Sizning kodingiz

# %% [markdown]
# ---
# ## 📝 Xulosa
#
# ### Nima qildingiz?
# 1. ✅ Ma'lumotlarni yuklab o'rgandingiz
# 2. ✅ Missing values ni to'ldirdingiz
# 3. ✅ Takroriy qatorlarni o'chirdingiz
# 4. ✅ Kategorik ma'lumotlarni encoding qildingiz
# 5. ✅ Ma'lumotlarni ML uchun tayyorladingiz
# 6. ✅ Vizualizatsiya va tahlil qildingiz
#
# ### Keyingi qadam?
# **Uy vazifasi** - yanada murakkab loyiha! 🚀
