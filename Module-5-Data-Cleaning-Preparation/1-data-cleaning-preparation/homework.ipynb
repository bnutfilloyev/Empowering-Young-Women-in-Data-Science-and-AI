# %% [markdown]
# # Uy Vazifasi: Data Tozalash va Tayyorlash
#
# ## 🎯 Maqsad
# Real dunyo ma'lumotlari bilan mustaqil ishlash va data cleaning pipeline yaratish.
#
# ## 📚 Vazifa
# Siz xodimlar bo'limi (HR) ma'lumotlari bilan ishlaysiz. Ma'lumotlar noto'liq va tartibsiz. Sizning vazifangiz - ma'lumotlarni tozalash va machine learning modeli uchun tayyorlash.
#
# ## ⏱️ Topshirish Muddati
# Keyingi darsga qadar
#
# ## 📊 Baholash Mezoni
# - Missing values to'ldirilishi (20 ball)
# - Takrorlar tozalanishi (15 ball)
# - Kategorik encoding (25 ball)
# - Vizualizatsiya va tahlil (20 ball)
# - Kod sifati va izohlar (20 ball)
#
# **Jami: 100 ball**

# %% [markdown]
# ## 📦 Kutubxonalarni Yuklash

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("Set2")
# %matplotlib inline

pd.set_option('display.max_columns', None)
print("✅ Kutubxonalar yuklandi!")

# %% [markdown]
# ---
# ## Qism 1: Ma'lumotlarni Yaratish va O'rganish (10 ball)

# %%
# Xodimlar ma'lumotlari
np.random.seed(123)

data = {
    'Xodim_ID': range(1, 51),
    'Ism': ['Ali', 'Vali', 'Sardor', 'Malika', 'Nigora'] * 10,
    'Yosh': np.random.choice([np.nan, 25, 28, 30, 32, 35, 38, 40, 42, 45], 50),
    'Jins': np.random.choice(['Erkak', 'Ayol'], 50),
    'Bo\'lim': np.random.choice(['IT', 'Moliya', 'Marketing', 'HR', np.nan], 50),
    'Lavozim': np.random.choice(['Junior', 'Middle', 'Senior', 'Lead', np.nan], 50),
    'Ish_Tajribasi': np.random.choice([np.nan, 1, 2, 3, 5, 7, 10, 12, 15], 50),
    'Maosh': np.random.choice([np.nan, 5000000, 7000000, 10000000, 15000000, 20000000, 25000000], 50),
    'Shartnoma': np.random.choice(['Doimiy', 'Vaqtinchalik', np.nan], 50),
    'Shahar': np.random.choice(['Toshkent', 'Samarqand', 'Buxoro', 'Farg\'ona', np.nan], 50),
    'Qoniqish_Darajasi': np.random.choice(['Past', 'O\'rta', 'Yuqori', np.nan], 50)
}

df = pd.DataFrame(data)

# Ba'zi takroriy qatorlar qo'shamiz
duplicate_rows = df.iloc[[0, 5, 10, 15, 20]].copy()
df = pd.concat([df, duplicate_rows], ignore_index=True)

print("📊 XODIMLAR MA'LUMOTLARI")
print(f"O'lcham: {df.shape}")
print("\nBirinchi 10 qator:")
print(df.head(10))

# %% [markdown]
# ### 📝 Topshiriq 1.1: Dastlabki Tahlil (5 ball)
#
# Ma'lumotlar haqida to'liq ma'lumot bering:
# - DataFrame o'lchami
# - Ustunlar va ularning data types
# - Asosiy statistik ma'lumotlar
# - Missing values soni

# %%
# TODO: Sizning kodingiz va tahlil
# 1. Shape

# 2. Info

# 3. Describe

# 4. Missing values

# %% [markdown]
# ### 📝 Topshiriq 1.2: Missing Values Vizualizatsiyasi (5 ball)
#
# Missing values ni vizualizatsiya qiling va har bir ustun uchun foizni hisoblang.

# %%
# TODO: Missing values vizualizatsiya (heatmap va bar chart)
# Sizning kodingiz

# %% [markdown]
# ---
# ## Qism 2: Missing Values ni To'ldirish (20 ball)
#
# ### 📝 Topshiriq 2.1: Strategiya Belgilash (5 ball)
#
# Har bir ustun uchun to'ldirish strategiyasini yozing va asoslang:
#
# | Ustun | Strategiya | Sabab |
# |-------|-----------|-------|
# | Yosh | ? | ? |
# | Bo'lim | ? | ? |
# | Lavozim | ? | ? |
# | Ish_Tajribasi | ? | ? |
# | Maosh | ? | ? |
# | Shartnoma | ? | ? |
# | Shahar | ? | ? |
# | Qoniqish_Darajasi | ? | ? |

# %%
# TODO: Strategiyani yozing (markdown yoki comment)
"""
MISSING VALUES STRATEGIYASI:

1. Yosh: 
   Strategiya: 
   Sabab: 

2. Bo'lim:
   Strategiya: 
   Sabab: 

...
"""

# %% [markdown]
# ### 📝 Topshiriq 2.2: Missing Values ni To'ldirish (15 ball)
#
# Belgilangan strategiya bo'yicha missing values ni to'ldiring.

# %%
# TODO: Missing values ni to'ldiring
df_cleaned = df.copy()

# 1. Raqamli ustunlar (Yosh, Ish_Tajribasi, Maosh)

# 2. Kategorik ustunlar (Bo'lim, Lavozim, Shartnoma, Shahar, Qoniqish_Darajasi)

# Tekshirish
print(f"Qolgan missing values: {df_cleaned.isnull().sum().sum()}")

# %% [markdown]
# ---
# ## Qism 3: Takroriy Ma'lumotlarni Tozalash (15 ball)
#
# ### 📝 Topshiriq 3.1: Takrorlarni Aniqlash (5 ball)

# %%
# TODO: Takroriy qatorlarni aniqlang (Xodim_ID dan tashqari)
# Sizning kodingiz

# Takroriy qatorlarni ko'rsating

# %% [markdown]
# ### 📝 Topshiriq 3.2: Takrorlarni O'chirish va Tahlil (10 ball)

# %%
# TODO: Takrorlarni o'chiring
# Sizning kodingiz

# Tahlil
print(f"Boshlang'ich qatorlar: {len(df)}")
print(f"Yakuniy qatorlar: {len(df_cleaned)}")
print(f"O'chirilgan: {len(df) - len(df_cleaned)} qator")

# %% [markdown]
# ---
# ## Qism 4: Kategorik Encoding (25 ball)
#
# ### 📝 Topshiriq 4.1: Encoding Strategiyasi (5 ball)
#
# Har bir kategorik ustun uchun encoding usulini tanlang va asoslang:
#
# | Ustun | Encoding Usuli | Sabab |
# |-------|---------------|-------|
# | Jins | ? | ? |
# | Bo'lim | ? | ? |
# | Lavozim | ? | ? |
# | Shartnoma | ? | ? |
# | Shahar | ? | ? |
# | Qoniqish_Darajasi | ? | ? |

# %%
# TODO: Encoding strategiyasini yozing
"""
ENCODING STRATEGIYASI:

1. Jins:
   Usul: 
   Sabab: 

2. Bo'lim:
   Usul: 
   Sabab: 

...
"""

# %% [markdown]
# ### 📝 Topshiriq 4.2: Label/Ordinal Encoding (10 ball)
#
# Binary va ordinal ustunlarni encoding qiling.

# %%
# TODO: Binary ustunlarni encode qiling (Jins, Shartnoma)
# Sizning kodingiz

# TODO: Ordinal ustunlarni encode qiling (Lavozim, Qoniqish_Darajasi)
# Masalan: Lavozim: Junior=0, Middle=1, Senior=2, Lead=3
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 4.3: One-Hot Encoding (10 ball)
#
# Nominal ustunlarni one-hot encoding qiling.

# %%
# TODO: Bo'lim va Shahar ustunlarini one-hot encode qiling
# Sizning kodingiz

print(f"Ustunlar soni: {len(df.columns)} → {len(df_cleaned.columns)}")

# %% [markdown]
# ---
# ## Qism 5: Feature Engineering (10 ball - Bonus)
#
# ### 📝 Topshiriq 5.1: Yangi Feature'lar Yaratish
#
# Quyidagi yangi feature'larni yarating:
# 1. `Maosh_per_Yil` = Yosh / Ish_Tajribasi (tajriba yiliga)
# 2. `Yosh_Guruhi`: 25-30, 31-35, 36-40, 41+
# 3. `Maosh_Kategoriya`: Past (<8M), O'rta (8-15M), Yuqori (>15M)

# %%
# TODO: Yangi feature'lar yarating
# Sizning kodingiz

# %% [markdown]
# ---
# ## Qism 6: Vizualizatsiya va Tahlil (20 ball)
#
# ### 📝 Topshiriq 6.1: Boshlang'ich vs Yakuniy Taqqoslash (5 ball)

# %%
# TODO: Comparison table yarating
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 6.2: Ma'lumotlar Taqsimoti (5 ball)

# %%
# TODO: Raqamli ustunlar uchun distribution plots (histogram/boxplot)
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 6.3: Correlation Analysis (5 ball)

# %%
# TODO: Correlation matrix yarating va heatmap chizing
# Sizning kodingiz

# %% [markdown]
# ### 📝 Topshiriq 6.4: Insight'lar (5 ball)
#
# Ma'lumotlar tahlilidan 5 ta muhim insight yozing:

# %% [markdown]
# **INSIGHT'LAR:**
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ---
# ## Qism 7: Yakuniy Pipeline (10 ball - Bonus)
#
# ### 📝 Topshiriq 7.1: Function Yaratish
#
# Butun data cleaning jarayonini bitta function sifatida yozing.

# %%
def clean_data(df):
    """
    Ma'lumotlarni tozalash va tayyorlash pipeline
    
    Parameters:
    df (DataFrame): Asl ma'lumotlar
    
    Returns:
    DataFrame: Tozalangan va encoded ma'lumotlar
    """
    # TODO: Sizning kodingiz
    
    return df_cleaned

# Test
# df_final = clean_data(df)
# print(df_final.head())

# %% [markdown]
# ---
# ## 📝 Yakuniy Hisobot
#
# ### Sizning Natijangiz:
#
# **Bajarilgan Vazifalar:**
# - [ ] Qism 1: Dastlabki tahlil (10 ball)
# - [ ] Qism 2: Missing values (20 ball)
# - [ ] Qism 3: Takrorlarni tozalash (15 ball)
# - [ ] Qism 4: Kategorik encoding (25 ball)
# - [ ] Qism 5: Feature engineering (10 ball - bonus)
# - [ ] Qism 6: Vizualizatsiya (20 ball)
# - [ ] Qism 7: Pipeline function (10 ball - bonus)
#
# **Jami ball:** ___/100 (+ bonus)
#
# ### O'zingiz Haqingizda:
#
# **Qiyinchiliklar:**
# -
#
# **O'rgangan Narsalar:**
# -
#
# **Keyingi Maqsadlar:**
# -

# %% [markdown]
# ---
# ## 📚 Qo'shimcha Resurslar
#
# 1. [Pandas Missing Data Guide](https://pandas.pydata.org/docs/user_guide/missing_data.html)
# 2. [Scikit-learn Preprocessing](https://scikit-learn.org/stable/modules/preprocessing.html)
# 3. [Feature Engineering Techniques](https://towardsdatascience.com/feature-engineering-for-machine-learning-3a5e293a5114)
#
# ---
#
# ## 🎉 Omad Tilaymiz!
#
# **Eslatma:** Kod yozishdan avval reja tuzing va strategiyani o'ylab ko'ring. Clean code va yaxshi izohlar muhim! 💪
