# %% [markdown]
# # Python Asoslari - Amaliy Mashqlar
#
# ## Maqsad
# Bu amaliy mashqlar orqali Python ning asosiy tushunchalarini mustahkamlash.
#
# ## Topshiriqlar ro'yxati:
# 1. **O'zgaruvchilar va ma'lumot turlari**
# 2. **Satrlar bilan ishlash**
# 3. **Ro'yxatlar va operatsiyalar**
# 4. **Shartli operatorlar**
# 5. **Tsikllar va iteratsiya**
#
# ---
#
# ### ⚠️ Eslatma:
# Har bir topshiriqni o'zingiz bajaring, so'ngra javoblarni tekshiring.
