# %% [markdown]
# # 📚 Uy vazifasi: Korrelyatsiya va Regressiya
#
# ## 🎯 Maqsad
# Darsda o'rgangan bilimlaringizni mustaqil ravishda qo'llash va chuqurlashtirish.
#
# ## ⏰ Vaqt: 2-3 soat
# ## 📊 Ball: 100 ball
#
# ## 📋 Vazifalar ro'yxati
# 1. **Ma'lumotlar tahlili** (20 ball)
# 2. **Korrelyatsiya tahlili** (25 ball)
# 3. **Regressiya modeli** (30 ball)
# 4. **Bashorat va baholash** (20 ball)
# 5. **Xulosa va tavsiyalar** (5 ball)
#
# ## 📝 Topshirish sharti
# - Barcha kod to'liq ishlashi kerak
# - Grafiklarda sarlavha, legend va izohlar bo'lishi kerak
# - Har bir natijani tushuntiring
# - Xulosa qismini to'ldiring

# %%
# Kutubxonalarni yuklash
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# Grafik sozlamalari
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (10, 6)
sns.set_palette("husl")

print("📚 Uy vazifasi boshlandi!")
print("💪 Omad tilaymiz!")

# %% [markdown]
# ## 📊 1. Ma'lumotlar tahlili (20 ball)
#
# ### Vazifa 1.1: Ma'lumotlarni yuklash va o'rganish (10 ball)

# %%
# Talabalar ma'lumotlarini yuklang
students = pd.read_csv('datasets/students_math.csv')

# VAZIFA: Ma'lumotlarni to'liq tahlil qiling
# 1. Ma'lumotlar o'lchamini ko'ring
# 2. Ustunlar ro'yxatini chiqaring
# 3. Yo'qolgan qiymatlarni tekshiring
# 4. Asosiy statistikalarni hisoblang
# 5. Ma'lumotlar turlarini ko'ring

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 1.2: Ma'lumotlar taqsimotini visuallashtirish (10 ball)

# %%
# VAZIFA: Barcha raqamli o'zgaruvchilar uchun histogramlar yarating
# Maslahat: plt.subplots() va for sikli ishlatish mumkin

# Sizning kodingiz:

# %% [markdown]
# ## 🔗 2. Korrelyatsiya tahlili (25 ball)
#
# ### Vazifa 2.1: Korrelyatsiya matritsasi (10 ball)

# %%
# VAZIFA: 
# 1. Barcha raqamli ustunlar uchun korrelyatsiya matritsasini hisoblang
# 2. Heatmap yarating
# 3. Eng kuchli korrelyatsiyalarni aniqlang

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 2.2: Pearson vs Spearman (15 ball)

# %%
# VAZIFA: O'qish soatlari va matematika bali uchun:
# 1. Pearson korrelyatsiyasini hisoblang
# 2. Spearman korrelyatsiyasini hisoblang  
# 3. Ikki natijani taqqoslang
# 4. Scatter plot yarating
# 5. Qaysi usul bu ma'lumotlar uchun yaxshiroq? Nima uchun?

# Sizning kodingiz:


# Javob (bu yerda izohingizni yozing):
#

# %% [markdown]
# ## 📈 3. Regressiya modeli (30 ball)
#
# ### Vazifa 3.1: Oddiy chiziqli regressiya (15 ball)

# %%
# VAZIFA: O'qish soatlari → Matematika bali uchun regressiya modeli yarating
# 1. X va y o'zgaruvchilarni aniqlang
# 2. LinearRegression modelini yarating
# 3. Modelni o'qiting
# 4. Og'ish va kesishma koeffitsiyentlarini chiqaring
# 5. Regressiya tenglamasini yozing

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 3.2: Qo'lda regressiya hisoblash (15 ball)

# %%
# VAZIFA: Regressiya koeffitsiyentlarini qo'lda hisoblang
# Formulalar:
# a = Σ[(xi - x̄)(yi - ȳ)] / Σ(xi - x̄)²
# b = ȳ - ax̄
# 
# 1. x va y o'rtacha qiymatlarini hisoblang
# 2. Og'ish koeffitsiyentini (a) hisoblang
# 3. Kesishma nuqtasini (b) hisoblang
# 4. sklearn natijasi bilan taqqoslang

# Sizning kodingiz:

# %% [markdown]
# ## 🎯 4. Bashorat va baholash (20 ball)
#
# ### Vazifa 4.1: Model sifatini baholash (10 ball)

# %%
# VAZIFA:
# 1. Bashorat qiling (y_pred)
# 2. R² ni hisoblang
# 3. RMSE ni hisoblang
# 4. MAE ni hisoblang
# 5. Model sifatini baholang (yaxshi/yomon?)

# Sizning kodingiz:


# Model sifati haqida fikringiz:
#

# %% [markdown]
# ### Vazifa 4.2: Model vizualizatsiyasi (10 ball)

# %%
# VAZIFA: 3 ta grafik yarating:
# 1. Scatter plot + regressiya chizig'i
# 2. Qoldiqlar grafigi (residuals plot)
# 3. Haqiqiy vs Bashorat grafigi

# Har bir grafikda:
# - To'g'ri sarlavha
# - O'q nomlari
# - Grid
# - Ranglar va stillar

# Sizning kodingiz:

# %% [markdown]
# ### Vazifa 4.3: Bashorat qilish (bonus 5 ball)

# %%
# VAZIFA: Quyidagi o'qish soatlari uchun matematika balini bashorat qiling:
test_hours = [1, 2.5, 4, 5.5, 7, 8]

# Har bir bashorat uchun:
# 1. Bashorat qiymatini hisoblang
# 2. Ishonch oralig'ini (±RMSE) ko'rsating
# 3. Bashorat ma'lumotlar oralig'ida yoki tashqaridami?

# Sizning kodingiz:

# %% [markdown]
# ## 📋 5. Xulosa va tavsiyalar (5 ball)
#
# ### Vazifa 5.1: Umumiy xulosa

# %% [markdown]
# **VAZIFA:** Quyidagi savollarga batafsil javob bering:
#
# ### 🤔 Tahlil natijalari:
# 1. **O'qish soatlari va matematika bali orasida qanday bog'lanish bor?**
#
#    Javob: _Bu yerda yozing_
#
# 2. **Korrelyatsiya koeffitsiyenti nimani bildiradi?**
#
#    Javob: _Bu yerda yozing_
#
# 3. **Regressiya modeli qanchalik yaxshi?**
#
#    Javob: _Bu yerda yozing_
#
# ### 💡 Amaliy tavsiyalar:
# 4. **Talabaga qancha o'qish tavsiya qilasiz?**
#
#    Javob: _Bu yerda yozing_
#
# 5. **Model cheklovlari nimalar?**
#
#    Javob: _Bu yerda yozing_
#
# ### ⚠️ Ogohlantirishlar:
# 6. **Korrelyatsiya sabab-oqibat ma'nosini beradimi?**
#
#    Javob: _Bu yerda yozing_
#
# 7. **Modelni qanday yaxshilash mumkin?**
#
#    Javob: _Bu yerda yozing_

# %% [markdown]
# ## 🏆 Qo'shimcha vazifalar (bonus ball)
#
# ### Bonus 1: Boshqa xususiyatlar bilan tajriba (+10 ball)
# 1. Uyqu soatlari va matematika bali orasidagi bog'lanishni tekshiring
# 2. Fizika va matematika bali orasidagi korrelyatsiyani hisoblang
# 3. Qaysi xususiyat eng yaxshi bashorat beradi?
#
# ### Bonus 2: Ma'lumotlarni tozalash (+5 ball)
# 1. Outlier'larni aniqlang (IQR usuli bilan)
# 2. Ularni olib tashlang
# 3. Model sifati yaxshiladimi?
#
# ### Bonus 3: Nochiziqli bog'lanish (+5 ball)
# 1. Boy va vazn orasidagi bog'lanishni tekshiring
# 2. Pearson va Spearman natijalarini taqqoslang
# 3. Qaysi korrelyatsiya turi yaxshiroq?
#
# ---
#
# ## 📤 Topshirish ko'rsatmalari
#
# ### ✅ Tekshirish ro'yxati:
# - [ ] Barcha kod ishlaydi
# - [ ] Grafiklar to'liq rasmlanadi
# - [ ] Hisoblashlar to'g'ri
# - [ ] Xulosa to'ldirilgan
# - [ ] Izohlar yozilgan
#
# ### 📊 Baholash mezonlari:
# - **90-100 ball**: A'lo - Barcha vazifalar mukammal bajarilgan
# - **80-89 ball**: Yaxshi - Kichik xatolar bor
# - **70-79 ball**: Qoniqarli - Ba'zi vazifalar bajarilmagan
# - **60-69 ball**: Yetarli - Ko'p xatolar bor
# - **<60 ball**: Qayta ishlash kerak
#
# ### 📅 Muddat: [O'qituvchi tomonidan belgilanadi]
#
# **Omad tilaymiz! 🍀**
