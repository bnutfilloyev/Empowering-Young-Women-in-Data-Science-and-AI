# %% [markdown]
# # Amaliy Mashqlar: Markaziy Tendentsiya va Tarqalish
# ## Markaziy Tendentsiya va Tarqalish bo'yicha Amaliy Mashqlar
#
# ### Ko'rsatmalar:
# 1. Avval individual mashqni bajaring
# 2. Keyin sizga tayinlangan guruh vazifasini bajaring
# 3. Faqat pandas va numpy kutubxonalaridan foydalaning
# 4. Hisob-kitoblaringizni qadam-baqadam ko'rsating
# 5. Natijalaringizni oddiy tilda talqin qiling
#
# ---

# %%
# Kerakli kutubxonalarni import qilish
import pandas as pd
import numpy as np

# %% [markdown]
# ## Individual Amaliy Mashq
# ### 1-Vazifa: Talabalar Natijalari Tahlili
#
# O'qituvchi 20 ta talabaning yakuniy imtihon baholarini qayd etdi:
#
# **Baholar:** [85, 92, 78, 96, 88, 74, 91, 83, 87, 95, 79, 89, 93, 82, 86, 90, 77, 94, 81, 88]
#
# **Sizning vazifalaringiz:**
# 1. O'rtacha, mediana va modani hisoblash
# 2. Diapaz, dispersiya va standart og'ishni hisoblash
# 3. Qaysi markaziy tendentsiya ko'rsatkichi eng mos ekanini talqin qilish
# 4. Standart og'ish baholar haqida nimani aytishini tushuntirish

# %%
# Individual Amaliy Mashq - Talaba Baholari
student_scores = [85, 92, 78, 96, 88, 74, 91, 83, 87, 95, 79, 89, 93, 82, 86, 90, 77, 94, 81, 88]

# 1-qadam: Osonroq tahlil uchun pandas Series ga aylantirish
scores_series = pd.Series(student_scores)

print("Talabalar Imtihon Baholari Tahlili")
print("=" * 40)
print(f"Baholar: {student_scores}")
print(f"Talabalar soni: {len(student_scores)}")

# TODO: Tahlilni yakunlang
# Markaziy tendentsiya ko'rsatkichlarini hisoblang

# Tarqalish ko'rsatkichlarini hisoblang

# Provide interpretation

# Your code here:

# %% [markdown]
# ## A-Guruh Vazifasi: Kompaniya Maosh Tahlili
# ### Ma'lumotlar to'plami: Texnologiya Kompaniyasi Maoshlari (USD)
#
# **A-Guruh uchun ko'rsatmalar:**
# Texnologiya startapi xodimlarning maoshlari haqida ma'lumotli qarorlar qabul qilish uchun tahlil qilishni xohlaydi.
#
# **Maosh ma'lumotlari (yillik, USD):**
# [45000, 52000, 48000, 65000, 58000, 72000, 61000, 55000, 67000, 59000, 63000, 56000, 69000, 120000, 51000, 62000, 57000, 64000, 60000, 68000]
#
# **Sizning guruh vazifalaringiz:**
# 1. Barcha markaziy tendentsiya va tarqalish ko'rsatkichlarini hisoblang
# 2. Haddan tashqari qiymatlar (outlier) borligini aniqlang va ularning ta'sirini tushuntiring
# 3. Kompaniya quyidagi maqsadlar uchun qaysi maosh ko'rsatkichidan (o'rtacha yoki mediana) foydalanishi kerakligini tavsiya eting:
#    - Byudjet rejalashtirish maqsadlari
#    - Ishga olish e'lonlari
#    - Ichki adolatlilik muhokamasi
# 4. Topilmalaringiz bilan xulosa hisoboti yarating
#
# **Javob berish kerak bo'lgan savollar:**
# - Bu kompaniyadagi tipik maosh nima?
# - Maoshlarda qanchalik farq bor?
# - Maoshlar adolatli taqsimlanganni?
# - HR bo'limiga qanday tavsiyalar berasiz?

# %%
# A-Guruh: Kompaniya Maosh Tahlili
company_salaries = [45000, 52000, 48000, 65000, 58000, 72000, 61000, 55000, 67000, 59000, 
                   63000, 56000, 69000, 120000, 51000, 62000, 57000, 64000, 60000, 68000]

print("Texnologiya Kompaniyasi Maosh Tahlili - A-Guruh")
print("=" * 50)

# Sizning guruh tahlilingiz:
# 1-qadam: Asosiy statistikalar

# 2-qadam: Haddan tashqari qiymatlarni aniqlash

# 3-qadam: O'rtacha vs mediana taqqoslash

# 4-qadam: Tavsiyalar

# A-Guruh kodi shu yerda:

# %% [markdown]
# ## B-Guruh Vazifasi: Shahar Harorat Tahlili
# ### Ma'lumotlar to'plami: Kunlik Haroratlar (°C)
#
# **B-Guruh uchun ko'rsatmalar:**
# Ob-havo stantsiyasi bir shahrda bir oy davomida kunlik maksimal haroratlarni to'pladi.
#
# **Harorat ma'lumotlari (°C):**
# [22, 25, 23, 27, 29, 24, 26, 28, 25, 23, 24, 26, 30, 28, 25, 27, 24, 26, 23, 25, 29, 27, 24, 26, 28, 25, 23, 27, 26, 24]
#
# **Sizning guruh vazifalaringiz:**
# 1. Barcha markaziy tendentsiya va tarqalish ko'rsatkichlarini hisoblang
# 2. Harorat o'zgaruvchanligini tahlil qiling
# 3. Haroratlar barqaror yoki juda o'zgaruvchan ekanligini aniqlang
# 4. Eng keng tarqalgan harorat oralig'ini aniqlang
# 5. Ob-havo xulosa hisobotini yarating
#
# **Javob berish kerak bo'lgan savollar:**
# - Bu oy uchun tipik harorat nima?
# - Kunlik haroratlar qanchalik bashorat qilish mumkin?
# - Odamlar ko'pincha qanday haroratni kutishlari kerak?
# - Ob-havo xizmati "o'rtacha" haroratni qanday e'lon qilishi kerak?

# %%
# B-Guruh: Shahar Harorat Tahlili
daily_temps = [22, 25, 23, 27, 29, 24, 26, 28, 25, 23, 24, 26, 30, 28, 25, 27, 24, 26, 
               23, 25, 29, 27, 24, 26, 28, 25, 23, 27, 26, 24]

print("Shahar Harorat Tahlili - B-Guruh")
print("=" * 50)

# Sizning guruh tahlilingiz:
# 1-qadam: Asosiy statistikalar

# 2-qadam: Harorat barqarorligi tahlili

# 3-qadam: Eng keng tarqalgan haroratlar

# 4-qadam: Ob-havo hisoboti tavsiyalari

# B-Guruh kodi shu yerda:

# %% [markdown]
# ## 🔑 Individual Amaliyot uchun Yechim
#
# Mana individual mashq uchun to'liq yechim:

# %%
# Individual Amaliyot uchun Yechim
student_scores = [85, 92, 78, 96, 88, 74, 91, 83, 87, 95, 79, 89, 93, 82, 86, 90, 77, 94, 81, 88]
scores_series = pd.Series(student_scores)

print("YECHIM - Talaba Baholari Tahlili")
print("=" * 50)

# Markaziy Tendentsiya
mean_score = scores_series.mean()
median_score = scores_series.median()
mode_score = scores_series.mode()

print(f"Markaziy Tendentsiya:")
print(f"  O'rtacha: {mean_score:.2f}")
print(f"  Mediana: {median_score:.2f}")
print(f"  Moda: {mode_score.values[0] if len(mode_score) > 0 else 'Yagona moda yo\'q'}")

# Tarqalish
range_score = scores_series.max() - scores_series.min()
variance_score = scores_series.var()
std_score = scores_series.std()

print(f"\nTarqalish:")
print(f"  Diapaz: {range_score}")
print(f"  Dispersiya: {variance_score:.2f}")
print(f"  Standart Og'ish: {std_score:.2f}")

print(f"\nTalqin:")
print(f"  - O'rtacha ({mean_score:.2f}) va mediana ({median_score:.2f}) juda yaqin,")
print(f"    bu ma'lumotlar taxminan simmetrik va katta haddan tashqari qiymatlar yo'qligini ko'rsatadi.")
print(f"  - {std_score:.2f} standart og'ish ko'pchilik talabalar")
print(f"    o'rtachadan {std_score:.2f} ball farqda ({mean_score:.2f} ball) olganini anglatadi.")
print(f"  - Bu o'rtacha darajadagi tarqalishni ifodalaydi.")

# %% [markdown]
# ## 🌟 Bonus Qo'shimcha Vazifa
#
# **O'rtacha o'quvchilar uchun:**
#
# Quyidagi stsenariyni tahlil qiling:
# - Kompaniya 2 ta mahsulot ishlab chiqaradi: A va B
# - A mahsulot: [100, 120, 110, 130, 105, 125, 115, 135, 108, 122] (ming so'm)
# - B mahsulot: [200, 180, 220, 160, 240, 190, 210, 170, 230, 200] (ming so'm)
#
# **Savollar:**
# 1. Qaysi mahsulot ko'proq barqaror (kam o'zgaruvchan) narxga ega?
# 2. Qaysi mahsulotning o'rtacha narxi yuqori?
# 3. Variatsiya koeffitsientini hisoblang va taqqoslang (CV = std/mean * 100%)

# %%
# Bonus Vazifa Yechimi
print("BONUS VAZIFA - Mahsulot Narxlari Taqqoslash")
print("=" * 55)

# Ma'lumotlar
product_a = [100, 120, 110, 130, 105, 125, 115, 135, 108, 122]
product_b = [200, 180, 220, 160, 240, 190, 210, 170, 230, 200]

a_series = pd.Series(product_a)
b_series = pd.Series(product_b)

# Asosiy statistikalar
print("MAHSULOT A (ming so'm):")
print(f"  O'rtacha: {a_series.mean():.1f}")
print(f"  Standart og'ish: {a_series.std():.2f}")

print("\nMAHSULOT B (ming so'm):")
print(f"  O'rtacha: {b_series.mean():.1f}")
print(f"  Standart og'ish: {b_series.std():.2f}")

# Variatsiya koeffitsienti
cv_a = (a_series.std() / a_series.mean()) * 100
cv_b = (b_series.std() / b_series.mean()) * 100

print(f"\nVARIATSIYA KOEFFITSIENTLARI:")
print(f"  Mahsulot A: {cv_a:.2f}%")
print(f"  Mahsulot B: {cv_b:.2f}%")

print(f"\nXULOSALAR:")
print(f"  1. Barqarorlik: {'A mahsulot' if cv_a < cv_b else 'B mahsulot'} ko'proq barqaror")
print(f"     (kichik variatsiya koeffitsienti)")
print(f"  2. O'rtacha narx: {'A mahsulot' if a_series.mean() > b_series.mean() else 'B mahsulot'} yuqori o'rtacha narxga ega")
print(f"  3. B mahsulot narxi yuqori lekin ko'proq o'zgaruvchan,")
print(f"     A mahsulot esa barqaror va bashorat qilish oson.")
